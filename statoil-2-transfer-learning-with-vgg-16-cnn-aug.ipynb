# %%
# Mandatory imports
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from os.path import join as opj
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pylab
plt.rcParams['figure.figsize'] = 10,10
# %matplotlib inline

# %%
train = pd.read_json('../input/iceberg-classifier-data/train.json')
target_train = train['is_iceberg']
test = pd.read_json('../input/iceberg-classifier-data/test.json')

# %%
target_train=train['is_iceberg']
test['inc_angle']=pd.to_numeric(test['inc_angle'], errors='coerce')
train['inc_angle']=pd.to_numeric(train['inc_angle'], errors='coerce')#We have only 133 NAs.
train['inc_angle']=train['inc_angle'].fillna(method='pad')
X_angle=train['inc_angle']
test['inc_angle']=pd.to_numeric(test['inc_angle'], errors='coerce')
X_test_angle=test['inc_angle']

#Generate the training data
X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
X_band_3=(X_band_1+X_band_2)/2
#X_band_3=np.array([np.full((75, 75), angel).astype(np.float32) for angel in train["inc_angle"]])
X_train = np.concatenate([X_band_1[:, :, :, np.newaxis]
                          , X_band_2[:, :, :, np.newaxis]
                         , X_band_3[:, :, :, np.newaxis]], axis=-1)



X_band_test_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in test["band_1"]])
X_band_test_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in test["band_2"]])
X_band_test_3=(X_band_test_1+X_band_test_2)/2
#X_band_test_3=np.array([np.full((75, 75), angel).astype(np.float32) for angel in test["inc_angle"]])
X_test = np.concatenate([X_band_test_1[:, :, :, np.newaxis]
                          , X_band_test_2[:, :, :, np.newaxis]
                         , X_band_test_3[:, :, :, np.newaxis]], axis=-1)

#Import Keras.
from matplotlib import pyplot
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, Activation
from keras.layers import GlobalMaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.merge import Concatenate
from keras.models import Model
from keras import initializers
from keras.optimizers import Adam
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping

from keras.datasets import cifar10
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.xception import Xception
from keras.applications.mobilenet import MobileNet
from keras.applications.vgg19 import VGG19
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input	

#Data Aug for multi-input
from keras.preprocessing.image import ImageDataGenerator
batch_size=64
# Define the image transformations here
gen = ImageDataGenerator(horizontal_flip = True,
                         vertical_flip = True,
                         width_shift_range = 0.,
                         height_shift_range = 0.,
                         channel_shift_range=0,
                         zoom_range = 0.2,
                         rotation_range = 10)

# Here is the function that merges our two generators
# We use the exact same generator with the same random seed for both the y and angle arrays
def gen_flow_for_two_inputs(X1, X2, y):
    genX1 = gen.flow(X1,y,  batch_size=batch_size,seed=55)
    genX2 = gen.flow(X1,X2, batch_size=batch_size,seed=55)
    while True:
            X1i = genX1.next()
            X2i = genX2.next()
            #Assert arrays are equal - this was for peace of mind, but slows down training
            #np.testing.assert_array_equal(X1i[0],X2i[0])
            yield [X1i[0], X2i[1]], X1i[1]

# Finally create generator
def get_callbacks(filepath, patience=2):
   es = EarlyStopping('val_loss', patience=10, mode="min")
   msave = ModelCheckpoint(filepath, save_best_only=True)
   return [es, msave]


def getVggAngleModel():
    input_2 = Input(shape=[1], name="angle")
    angle_layer = Dense(1, )(input_2)
    base_model = VGG16(weights='imagenet', include_top=False, 
                 input_shape=X_train.shape[1:], classes=1)
    
    x = base_model.get_layer('block5_pool').output
    
    x = GlobalMaxPooling2D()(x)
    merge_one = concatenate([x, angle_layer])
    merge_one = Dense(512, activation='relu', name='fc2')(merge_one)
    merge_one = Dropout(0.3)(merge_one)
    merge_one = Dense(512, activation='relu', name='fc3')(merge_one)
    merge_one = Dropout(0.3)(merge_one)
    
    predictions = Dense(1, activation='sigmoid')(merge_one)
    
    model = Model([base_model.input, input_2], predictions)
    
    
    sgd = SGD(lr=1e-3, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(loss='binary_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy'])
    return model

# %%
#Using K-fold Cross Validation with Data Augmentation.
def myAngleCV(X_train, X_angle, X_test):
    K=3
    folds = list(StratifiedKFold(n_splits=K, shuffle=True, random_state=16).split(X_train, target_train))
    y_test_pred_log = 0
    y_train_pred_log=0
    y_valid_pred_log = 0.0*target_train
    for j, (train_idx, test_idx) in enumerate(folds):
        print('\n===================FOLD=',j)
        X_train_cv = X_train[train_idx]
        y_train_cv = target_train[train_idx]
        X_holdout = X_train[test_idx]
        Y_holdout= target_train[test_idx]
        
        #Angle
        X_angle_cv=X_angle[train_idx]
        X_angle_hold=X_angle[test_idx]

        #define file path and get callbacks
        file_path = "%s_aug_model_weights.hdf5"%j
        callbacks = get_callbacks(filepath=file_path, patience=5)
        gen_flow = gen_flow_for_two_inputs(X_train_cv, X_angle_cv, y_train_cv)
        galaxyModel= getVggAngleModel()
        galaxyModel.fit_generator(
                gen_flow,
                steps_per_epoch=24,
                epochs=100,
                shuffle=True,
                verbose=1,
                validation_data=([X_holdout,X_angle_hold], Y_holdout),
                callbacks=callbacks)

        #Getting the Best Model
        galaxyModel.load_weights(filepath=file_path)
        #Getting Training Score
        score = galaxyModel.evaluate([X_train_cv,X_angle_cv], y_train_cv, verbose=0)
        print('Train loss:', score[0])
        print('Train accuracy:', score[1])
        #Getting Test Score
        score = galaxyModel.evaluate([X_holdout,X_angle_hold], Y_holdout, verbose=0)
        print('Test loss:', score[0])
        print('Test accuracy:', score[1])

        #Getting validation Score.
        pred_valid=galaxyModel.predict([X_holdout,X_angle_hold])
        y_valid_pred_log[test_idx] = pred_valid.reshape(pred_valid.shape[0])

        #Getting Test Scores
        temp_test=galaxyModel.predict([X_test, X_test_angle])
        y_test_pred_log+=temp_test.reshape(temp_test.shape[0])

        #Getting Train Scores
        temp_train=galaxyModel.predict([X_train, X_angle])
        y_train_pred_log+=temp_train.reshape(temp_train.shape[0])

    y_test_pred_log=y_test_pred_log/K
    y_train_pred_log=y_train_pred_log/K

    print('\n Train Log Loss Validation= ',log_loss(target_train, y_train_pred_log))
    print(' Test Log Loss Validation= ',log_loss(target_train, y_valid_pred_log))
    return y_test_pred_log

# %%
preds =myAngleCV(X_train, X_angle, X_test)
# Out:
# ===================FOLD= 0
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 24/24 [==============================] - 9s 213ms/step - loss: 0.9772 - accuracy: 0.5639 - val_loss: 0.3604 - val_accuracy: 0.8374
# Epoch 2/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.5158 - accuracy: 0.7523 - val_loss: 0.3195 - val_accuracy: 0.8467
# Epoch 3/100
# 24/24 [==============================] - 5s 204ms/step - loss: 0.3717 - accuracy: 0.8336 - val_loss: 0.2569 - val_accuracy: 0.8972
# Epoch 4/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.3028 - accuracy: 0.8757 - val_loss: 0.2901 - val_accuracy: 0.8673
# Epoch 5/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.3054 - accuracy: 0.8771 - val_loss: 0.2450 - val_accuracy: 0.9009
# Epoch 6/100
# 24/24 [==============================] - 4s 166ms/step - loss: 0.2679 - accuracy: 0.8903 - val_loss: 0.2307 - val_accuracy: 0.9028
# Epoch 7/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.2157 - accuracy: 0.9138 - val_loss: 0.2238 - val_accuracy: 0.9084
# Epoch 8/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.2292 - accuracy: 0.9053 - val_loss: 0.2368 - val_accuracy: 0.9140
# Epoch 9/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.2119 - accuracy: 0.9083 - val_loss: 0.2457 - val_accuracy: 0.9215
# Epoch 10/100
# 24/24 [==============================] - 4s 187ms/step - loss: 0.1891 - accuracy: 0.9231 - val_loss: 0.2212 - val_accuracy: 0.9215
# Epoch 11/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.1822 - accuracy: 0.9356 - val_loss: 0.2240 - val_accuracy: 0.9121
# Epoch 12/100
# 24/24 [==============================] - 4s 171ms/step - loss: 0.1943 - accuracy: 0.9128 - val_loss: 0.2365 - val_accuracy: 0.9121
# Epoch 13/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.1640 - accuracy: 0.9286 - val_loss: 0.2508 - val_accuracy: 0.9084
# Epoch 14/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.1633 - accuracy: 0.9375 - val_loss: 0.2507 - val_accuracy: 0.9009
# Epoch 15/100
# 24/24 [==============================] - 4s 164ms/step - loss: 0.1694 - accuracy: 0.9351 - val_loss: 0.2303 - val_accuracy: 0.9103
# Epoch 16/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.1737 - accuracy: 0.9359 - val_loss: 0.2664 - val_accuracy: 0.8953
# Epoch 17/100
# 24/24 [==============================] - 4s 169ms/step - loss: 0.1536 - accuracy: 0.9476 - val_loss: 0.2322 - val_accuracy: 0.9103
# Epoch 18/100
# 24/24 [==============================] - 4s 189ms/step - loss: 0.1331 - accuracy: 0.9478 - val_loss: 0.2444 - val_accuracy: 0.9047
# Epoch 19/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.1358 - accuracy: 0.9545 - val_loss: 0.2468 - val_accuracy: 0.9121
# Epoch 20/100
# 24/24 [==============================] - 4s 166ms/step - loss: 0.1549 - accuracy: 0.9405 - val_loss: 0.2429 - val_accuracy: 0.9084
# Train loss: 0.15267233550548553
# Train accuracy: 0.9457436800003052
# Test loss: 0.22116300463676453
# Test accuracy: 0.9214953184127808
#
# ===================FOLD= 1
# Epoch 1/100
# 24/24 [==============================] - 5s 184ms/step - loss: 0.7365 - accuracy: 0.5685 - val_loss: 0.5842 - val_accuracy: 0.6841
# Epoch 2/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.4442 - accuracy: 0.7723 - val_loss: 0.2898 - val_accuracy: 0.8879
# Epoch 3/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.3215 - accuracy: 0.8635 - val_loss: 0.2562 - val_accuracy: 0.8953
# Epoch 4/100
# 24/24 [==============================] - 4s 189ms/step - loss: 0.2865 - accuracy: 0.8671 - val_loss: 0.2335 - val_accuracy: 0.9047
# Epoch 5/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.2790 - accuracy: 0.8745 - val_loss: 0.2272 - val_accuracy: 0.9047
# Epoch 6/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.2648 - accuracy: 0.8880 - val_loss: 0.2339 - val_accuracy: 0.8860
# Epoch 7/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.2558 - accuracy: 0.8848 - val_loss: 0.2282 - val_accuracy: 0.9028
# Epoch 8/100
# 24/24 [==============================] - 4s 165ms/step - loss: 0.2120 - accuracy: 0.9073 - val_loss: 0.2116 - val_accuracy: 0.9140
# Epoch 9/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.2498 - accuracy: 0.8987 - val_loss: 0.2170 - val_accuracy: 0.8972
# Epoch 10/100
# 24/24 [==============================] - 4s 182ms/step - loss: 0.2302 - accuracy: 0.9046 - val_loss: 0.2085 - val_accuracy: 0.9103
# Epoch 11/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.2122 - accuracy: 0.9205 - val_loss: 0.2168 - val_accuracy: 0.9178
# Epoch 12/100
# 24/24 [==============================] - 4s 191ms/step - loss: 0.1811 - accuracy: 0.9315 - val_loss: 0.2144 - val_accuracy: 0.9215
# Epoch 13/100
# 24/24 [==============================] - 4s 174ms/step - loss: 0.1794 - accuracy: 0.9157 - val_loss: 0.2130 - val_accuracy: 0.9290
# Epoch 14/100
# 24/24 [==============================] - 4s 166ms/step - loss: 0.1887 - accuracy: 0.9287 - val_loss: 0.2028 - val_accuracy: 0.9178
# Epoch 15/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.1703 - accuracy: 0.9336 - val_loss: 0.2434 - val_accuracy: 0.9178
# Epoch 16/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.1672 - accuracy: 0.9283 - val_loss: 0.2994 - val_accuracy: 0.9252
# Epoch 17/100
# 24/24 [==============================] - 4s 164ms/step - loss: 0.1756 - accuracy: 0.9334 - val_loss: 0.3045 - val_accuracy: 0.8860
# Epoch 18/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.1639 - accuracy: 0.9403 - val_loss: 0.2015 - val_accuracy: 0.9178
# Epoch 19/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.1559 - accuracy: 0.9350 - val_loss: 0.2225 - val_accuracy: 0.9065
# Epoch 20/100
# 24/24 [==============================] - 5s 198ms/step - loss: 0.1600 - accuracy: 0.9354 - val_loss: 0.2015 - val_accuracy: 0.9140
# Epoch 21/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.1314 - accuracy: 0.9468 - val_loss: 0.2089 - val_accuracy: 0.9047
# Epoch 22/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.1575 - accuracy: 0.9422 - val_loss: 0.2419 - val_accuracy: 0.8972
# Epoch 23/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.1359 - accuracy: 0.9418 - val_loss: 0.2362 - val_accuracy: 0.9234
# Epoch 24/100
# 24/24 [==============================] - 4s 173ms/step - loss: 0.1385 - accuracy: 0.9448 - val_loss: 0.2717 - val_accuracy: 0.8897
# Epoch 25/100
# 24/24 [==============================] - 4s 165ms/step - loss: 0.1431 - accuracy: 0.9362 - val_loss: 0.2435 - val_accuracy: 0.9103
# Epoch 26/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.1084 - accuracy: 0.9591 - val_loss: 0.2640 - val_accuracy: 0.9047
# Epoch 27/100
# 24/24 [==============================] - 4s 182ms/step - loss: 0.1205 - accuracy: 0.9522 - val_loss: 0.2838 - val_accuracy: 0.9028
# Epoch 28/100
# 24/24 [==============================] - 4s 169ms/step - loss: 0.1353 - accuracy: 0.9484 - val_loss: 0.3771 - val_accuracy: 0.8766
# Train loss: 0.12902230024337769
# Train accuracy: 0.9438727498054504
# Test loss: 0.20150020718574524
# Test accuracy: 0.9177570343017578
#
# ===================FOLD= 2
# Epoch 1/100
# 24/24 [==============================] - 7s 268ms/step - loss: 1.1280 - accuracy: 0.5585 - val_loss: 0.4771 - val_accuracy: 0.7528
# Epoch 2/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.5021 - accuracy: 0.7644 - val_loss: 0.3632 - val_accuracy: 0.8258
# Epoch 3/100
# 24/24 [==============================] - 4s 166ms/step - loss: 0.3664 - accuracy: 0.8504 - val_loss: 0.3053 - val_accuracy: 0.8652
# Epoch 4/100
# 24/24 [==============================] - 4s 177ms/step - loss: 0.3094 - accuracy: 0.8645 - val_loss: 0.2694 - val_accuracy: 0.8727
# Epoch 5/100
# 24/24 [==============================] - 4s 187ms/step - loss: 0.3102 - accuracy: 0.8639 - val_loss: 0.2674 - val_accuracy: 0.8858
# Epoch 6/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.2396 - accuracy: 0.8905 - val_loss: 0.2734 - val_accuracy: 0.8764
# Epoch 7/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.2370 - accuracy: 0.9085 - val_loss: 0.2596 - val_accuracy: 0.8820
# Epoch 8/100
# 24/24 [==============================] - 4s 176ms/step - loss: 0.2259 - accuracy: 0.9020 - val_loss: 0.2947 - val_accuracy: 0.8652
# Epoch 9/100
# 24/24 [==============================] - 4s 180ms/step - loss: 0.2398 - accuracy: 0.8991 - val_loss: 0.2592 - val_accuracy: 0.8970
# Epoch 10/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.2117 - accuracy: 0.9115 - val_loss: 0.2749 - val_accuracy: 0.8839
# Epoch 11/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.1976 - accuracy: 0.9193 - val_loss: 0.2977 - val_accuracy: 0.8895
# Epoch 12/100
# 24/24 [==============================] - 4s 187ms/step - loss: 0.1903 - accuracy: 0.9219 - val_loss: 0.2892 - val_accuracy: 0.8764
# Epoch 13/100
# 24/24 [==============================] - 4s 168ms/step - loss: 0.2101 - accuracy: 0.9185 - val_loss: 0.2680 - val_accuracy: 0.9026
# Epoch 14/100
# 24/24 [==============================] - 4s 179ms/step - loss: 0.1980 - accuracy: 0.9183 - val_loss: 0.2427 - val_accuracy: 0.9007
# Epoch 15/100
# 24/24 [==============================] - 4s 171ms/step - loss: 0.1898 - accuracy: 0.9177 - val_loss: 0.2459 - val_accuracy: 0.8989
# Epoch 16/100
# 24/24 [==============================] - 4s 169ms/step - loss: 0.1511 - accuracy: 0.9369 - val_loss: 0.2845 - val_accuracy: 0.8989
# Epoch 17/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.1871 - accuracy: 0.9239 - val_loss: 0.2858 - val_accuracy: 0.8989
# Epoch 18/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.1412 - accuracy: 0.9446 - val_loss: 0.3149 - val_accuracy: 0.8839
# Epoch 19/100
# 24/24 [==============================] - 4s 178ms/step - loss: 0.1699 - accuracy: 0.9196 - val_loss: 0.2777 - val_accuracy: 0.8895
# Epoch 20/100
# 24/24 [==============================] - 4s 187ms/step - loss: 0.1601 - accuracy: 0.9375 - val_loss: 0.2742 - val_accuracy: 0.8933
# Epoch 21/100
# 24/24 [==============================] - 4s 167ms/step - loss: 0.1358 - accuracy: 0.9457 - val_loss: 0.2793 - val_accuracy: 0.9045
# Epoch 22/100
# 24/24 [==============================] - 4s 175ms/step - loss: 0.1507 - accuracy: 0.9400 - val_loss: 0.2586 - val_accuracy: 0.9101
# Epoch 23/100
# 24/24 [==============================] - 4s 181ms/step - loss: 0.1250 - accuracy: 0.9479 - val_loss: 0.2581 - val_accuracy: 0.9082
# Epoch 24/100
# 24/24 [==============================] - 4s 169ms/step - loss: 0.1232 - accuracy: 0.9524 - val_loss: 0.2996 - val_accuracy: 0.8989
# Train loss: 0.13489949703216553
# Train accuracy: 0.9448598027229309
# Test loss: 0.24271664023399353
# Test accuracy: 0.9007490873336792
#
#  Train Log Loss Validation=  0.14528732418668974
#  Test Log Loss Validation=  0.2217802251763173

# %%
#Submission for each day.
submission = pd.DataFrame()
submission['id']=test['id']
submission['is_iceberg']=preds
submission.to_csv('sub.csv', index=False)
