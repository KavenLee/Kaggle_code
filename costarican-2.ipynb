# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=2.2)
plt.style.use('seaborn')

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import StratifiedKFold, train_test_split, ShuffleSplit
from sklearn.metrics import f1_score
import itertools
import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBClassifier
import shap
from tqdm import tqdm
import featuretools as ft
import warnings 
warnings.filterwarnings('ignore')
import time

# %% [markdown]
# # 1. Check datasets

# %% [markdown]
# ## 1.1 Read dataset

# %%
df_train = pd.read_csv('C:/Users/User/ML/data/train.csv')
df_test = pd.read_csv('C:/Users/User/ML/data/test.csv')

# %%
print('df_train shape : ', df_train.shape, '  ', 'df_test shape : ', df_test.shape)
# Out:
# df_train shape :  (9557, 143)    df_test shape :  (23856, 142)

# %%
df_train.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  SQBhogar_nin  \
# 0     0  ...          100    1849               1        100             0
# 1     0  ...          144    4489               1        144             0
# 2     0  ...          121    8464               1          0             0
# 3     0  ...           81     289              16        121             4
# 4     0  ...          121    1369              16        121             4
#
#    SQBovercrowding  SQBdependency  SQBmeaned  agesq  Target
# 0         1.000000            0.0      100.0   1849       4
# 1         1.000000           64.0      144.0   4489       4
# 2         0.250000           64.0      121.0   8464       4
# 3         1.777778            1.0      121.0    289       4
# 4         1.777778            1.0      121.0   1369       4
#
# [5 rows x 143 columns]

# %%
df_test.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_2f6873615       NaN       0      5       0     1       1     0    NaN
# 1  ID_1c78846d2       NaN       0      5       0     1       1     0    NaN
# 2  ID_e5442cf6a       NaN       0      5       0     1       1     0    NaN
# 3  ID_a8db26a79       NaN       0     14       0     1       1     1    1.0
# 4  ID_a62966799  175000.0       0      4       0     1       1     1    1.0
#
#    r4h1  ...  age  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 0     1  ...    4            0      16               9          0
# 1     1  ...   41          256    1681               9          0
# 2     1  ...   41          289    1681               9          0
# 3     0  ...   59          256    3481               1        256
# 4     0  ...   18          121     324               1          0
#
#    SQBhogar_nin  SQBovercrowding  SQBdependency  SQBmeaned  agesq
# 0             1             2.25           0.25     272.25     16
# 1             1             2.25           0.25     272.25   1681
# 2             1             2.25           0.25     272.25   1681
# 3             0             1.00           0.00     256.00   3481
# 4             1             0.25          64.00        NaN    324
#
# [5 rows x 142 columns]

# %% [markdown]
# ## 1.2 Make description df

# %%
description = [
("v2a1"," Monthly rent payment"),
("hacdor"," =1 Overcrowding by bedrooms"),
("rooms","  number of all rooms in the house"),
("hacapo"," =1 Overcrowding by rooms"),
("v14a"," =1 has toilet in the household"),
("refrig"," =1 if the household has refrigerator"),
("v18q"," owns a tablet"),
("v18q1"," number of tablets household owns"),
("r4h1"," Males younger than 12 years of age"),
("r4h2"," Males 12 years of age and older"),
("r4h3"," Total males in the household"),
("r4m1"," Females younger than 12 years of age"),
("r4m2"," Females 12 years of age and older"),
("r4m3"," Total females in the household"),
("r4t1"," persons younger than 12 years of age"),
("r4t2"," persons 12 years of age and older"),
("r4t3"," Total persons in the household"),
("tamhog"," size of the household"),
("tamviv"," number of persons living in the household"),
("escolari"," years of schooling"),
("rez_esc"," Years behind in school"),
("hhsize"," household size"),
("paredblolad"," =1 if predominant material on the outside wall is block or brick"),
("paredzocalo"," =1 if predominant material on the outside wall is socket (wood, zinc or absbesto"),
("paredpreb"," =1 if predominant material on the outside wall is prefabricated or cement"),
("pareddes"," =1 if predominant material on the outside wall is waste material"),
("paredmad"," =1 if predominant material on the outside wall is wood"),
("paredzinc"," =1 if predominant material on the outside wall is zink"),
("paredfibras"," =1 if predominant material on the outside wall is natural fibers"),
("paredother"," =1 if predominant material on the outside wall is other"),
("pisomoscer"," =1 if predominant material on the floor is mosaic ceramic   terrazo"),
("pisocemento"," =1 if predominant material on the floor is cement"),
("pisoother"," =1 if predominant material on the floor is other"),
("pisonatur"," =1 if predominant material on the floor is  natural material"),
("pisonotiene"," =1 if no floor at the household"),
("pisomadera"," =1 if predominant material on the floor is wood"),
("techozinc"," =1 if predominant material on the roof is metal foil or zink"),
("techoentrepiso"," =1 if predominant material on the roof is fiber cement,   mezzanine "),
("techocane"," =1 if predominant material on the roof is natural fibers"),
("techootro"," =1 if predominant material on the roof is other"),
("cielorazo"," =1 if the house has ceiling"),
("abastaguadentro"," =1 if water provision inside the dwelling"),
("abastaguafuera"," =1 if water provision outside the dwelling"),
("abastaguano"," =1 if no water provision"),
("public"," =1 electricity from CNFL,  ICE, ESPH/JASEC"),
("planpri"," =1 electricity from private plant"),
("noelec"," =1 no electricity in the dwelling"),
("coopele"," =1 electricity from cooperative"),
("sanitario1"," =1 no toilet in the dwelling"),
("sanitario2"," =1 toilet connected to sewer or cesspool"),
("sanitario3"," =1 toilet connected to  septic tank"),
("sanitario5"," =1 toilet connected to black hole or letrine"),
("sanitario6"," =1 toilet connected to other system"),
("energcocinar1"," =1 no main source of energy used for cooking (no kitchen)"),
("energcocinar2"," =1 main source of energy used for cooking electricity"),
("energcocinar3"," =1 main source of energy used for cooking gas"),
("energcocinar4"," =1 main source of energy used for cooking wood charcoal"),
("elimbasu1"," =1 if rubbish disposal mainly by tanker truck"),
("elimbasu2"," =1 if rubbish disposal mainly by botan hollow or buried"),
("elimbasu3"," =1 if rubbish disposal mainly by burning"),
("elimbasu4"," =1 if rubbish disposal mainly by throwing in an unoccupied space"),
("elimbasu5"," =1 if rubbish disposal mainly by throwing in river,   creek or sea"),
("elimbasu6"," =1 if rubbish disposal mainly other"),
("epared1"," =1 if walls are bad"),
("epared2"," =1 if walls are regular"),
("epared3"," =1 if walls are good"),
("etecho1"," =1 if roof are bad"),
("etecho2"," =1 if roof are regular"),
("etecho3"," =1 if roof are good"),
("eviv1"," =1 if floor are bad"),
("eviv2"," =1 if floor are regular"),
("eviv3"," =1 if floor are good"),
("dis"," =1 if disable person"),
("male"," =1 if male"),
("female"," =1 if female"),
("estadocivil1"," =1 if less than 10 years old"),
("estadocivil2"," =1 if free or coupled uunion"),
("estadocivil3"," =1 if married"),
("estadocivil4"," =1 if divorced"),
("estadocivil5"," =1 if separated"),
("estadocivil6"," =1 if widow/er"),
("estadocivil7"," =1 if single"),
("parentesco1"," =1 if household head"),
("parentesco2"," =1 if spouse/partner"),
("parentesco3"," =1 if son/doughter"),
("parentesco4"," =1 if stepson/doughter"),
("parentesco5"," =1 if son/doughter in law"),
("parentesco6"," =1 if grandson/doughter"),
("parentesco7"," =1 if mother/father"),
("parentesco8"," =1 if father/mother in law"),
("parentesco9"," =1 if brother/sister"),
("parentesco10"," =1 if brother/sister in law"),
("parentesco11"," =1 if other family member"),
("parentesco12"," =1 if other non family member"),
("idhogar"," Household level identifier"),
("hogar_nin"," Number of children 0 to 19 in household"),
("hogar_adul"," Number of adults in household"),
("hogar_mayor"," # of individuals 65+ in the household"),
("hogar_total"," # of total individuals in the household"),
("dependency"," Dependency rate"),
("edjefe"," years of education of male head of household"),
("edjefa"," years of education of female head of household"),
("meaneduc","average years of education for adults (18+)"),
("instlevel1"," =1 no level of education"),
("instlevel2"," =1 incomplete primary"),
("instlevel3"," =1 complete primary"),
("instlevel4"," =1 incomplete academic secondary level"),
("instlevel5"," =1 complete academic secondary level"),
("instlevel6"," =1 incomplete technical secondary level"),
("instlevel7"," =1 complete technical secondary level"),
("instlevel8"," =1 undergraduate and higher education"),
("instlevel9"," =1 postgraduate higher education"),
("bedrooms"," number of bedrooms"),
("overcrowding"," # persons per room"),
("tipovivi1"," =1 own and fully paid house"),
("tipovivi2"," =1 own,   paying in installments"),
("tipovivi3"," =1 rented"),
("tipovivi4"," =1 precarious"),
("tipovivi5"," =1 other(assigned"),
("computer"," =1 if the household has notebook or desktop computer,   borrowed)"),
("television"," =1 if the household has TV"),
("mobilephone"," =1 if mobile phone"),
("qmobilephone"," # of mobile phones"),
("lugar1"," =1 region Central"),
("lugar2"," =1 region Chorotega"),
("lugar3"," =1 region PacÃƒÂ­fico central"),
("lugar4"," =1 region Brunca"),
("lugar5"," =1 region Huetar AtlÃƒÂ¡ntica"),
("lugar6"," =1 region Huetar Norte"),
("area1"," =1 zona urbana"),
("area2"," =2 zona rural"),
("age"," Age in years"),
("SQBescolari"," escolari squared"),
("SQBage"," age squared"),
("SQBhogar_total"," hogar_total squared"),
("SQBedjefe"," edjefe squared"),
("SQBhogar_nin"," hogar_nin squared"),
("SQBovercrowding"," overcrowding squared"),
("SQBdependency"," dependency squared"),
("SQBmeaned"," meaned squared"),
("agesq"," Age squared"),]

description = pd.DataFrame(description, columns=['varname', 'description'])

# %%
description
# Out:
#              varname                         description
# 0               v2a1                Monthly rent payment
# 1             hacdor         =1 Overcrowding by bedrooms
# 2              rooms    number of all rooms in the house
# 3             hacapo            =1 Overcrowding by rooms
# 4               v14a      =1 has toilet in the household
# ..               ...                                 ...
# 136     SQBhogar_nin                   hogar_nin squared
# 137  SQBovercrowding                overcrowding squared
# 138    SQBdependency                  dependency squared
# 139        SQBmeaned                      meaned squared
# 140            agesq                         Age squared
#
# [141 rows x 2 columns]

# %% [markdown]
# ## 1.3 Check null data

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#                  Total    Percent
# rez_esc           7928  82.954902
# v18q1             7342  76.823271
# v2a1              6860  71.779847
# meaneduc             5   0.052318
# SQBmeaned            5   0.052318
# techozinc            0   0.000000
# techoentrepiso       0   0.000000
# techocane            0   0.000000
# techootro            0   0.000000
# cielorazo            0   0.000000
# abastaguadentro      0   0.000000
# sanitario3           0   0.000000
# abastaguafuera       0   0.000000
# abastaguano          0   0.000000
# public               0   0.000000
# planpri              0   0.000000
# noelec               0   0.000000
# coopele              0   0.000000
# sanitario1           0   0.000000
# sanitario2           0   0.000000

# %% [markdown]
# ## 1.4 Filll missing values

# %%
# if education is "yes" and person is head of household, fill with escolari
df_train.loc[(df_train['edjefa'] == "yes") & (df_train['parentesco1'] == 1), "edjefa"] = df_train.loc[(df_train['edjefa'] == "yes") & (df_train['parentesco1'] == 1), "escolari"]
df_train.loc[(df_train['edjefe'] == "yes") & (df_train['parentesco1'] == 1), "edjefe"] = df_train.loc[(df_train['edjefe'] == "yes") & (df_train['parentesco1'] == 1), "escolari"]

df_test.loc[(df_test['edjefa'] == "yes") & (df_test['parentesco1'] == 1), "edjefa"] = df_test.loc[(df_test['edjefa'] == "yes") & (df_test['parentesco1'] == 1), "escolari"]
df_test.loc[(df_test['edjefe'] == "yes") & (df_test['parentesco1'] == 1), "edjefe"] = df_test.loc[(df_test['edjefe'] == "yes") & (df_test['parentesco1'] == 1), "escolari"]

# this field is supposed to be interaction between gender and escolari, but it isn't clear what "yes" means, let's fill it with 4
df_train.loc[df_train['edjefa'] == "yes", "edjefa"] = 4
df_train.loc[df_train['edjefe'] == "yes", "edjefe"] = 4

df_test.loc[df_test['edjefa'] == "yes", "edjefa"] = 4
df_test.loc[df_test['edjefe'] == "yes", "edjefe"] = 4

# create feature with max education of either head of household
df_train['edjef'] = np.max(df_train[['edjefa','edjefe']], axis=1)
df_test['edjef'] = np.max(df_test[['edjefa','edjefe']], axis=1)

# fix some inconsistencies in the data - some rows indicate both that the household does and does not have a toilet, 
# if there is no water we'll assume they do not
df_train.loc[(df_train.v14a ==  1) & (df_train.sanitario1 ==  1) & (df_train.abastaguano == 0), "v14a"] = 0
df_train.loc[(df_train.v14a ==  1) & (df_train.sanitario1 ==  1) & (df_train.abastaguano == 0), "sanitario1"] = 0

df_test.loc[(df_test.v14a ==  1) & (df_test.sanitario1 ==  1) & (df_test.abastaguano == 0), "v14a"] = 0
df_test.loc[(df_test.v14a ==  1) & (df_test.sanitario1 ==  1) & (df_test.abastaguano == 0), "sanitario1"] = 0

# %% [markdown]
# ### rez_esz, SQBmeaned

# %%
df_train['rez_esc'].fillna(0, inplace=True)
df_test['rez_esc'].fillna(0, inplace=True)

# %%
df_train['SQBmeaned'].fillna(0,inplace=True)
df_test['SQBmeaned'].fillna(0,inplace=True)

# %% [markdown]
# ### meaneduc

# %%
df_train['meaneduc'].fillna(0,inplace=True)
df_test['meaneduc'].fillna(0,inplace=True)

# %% [markdown]
# ### v18q1

# %%
df_train['v18q'].value_counts()
# Out:
# 0    7342
# 1    2215
# Name: v18q, dtype: int64

# %%
df_train.loc[df_train['v18q']==1,'v18q1'].value_counts()
# Out:
# 1.0    1586
# 2.0     444
# 3.0     129
# 4.0      37
# 5.0      13
# 6.0       6
# Name: v18q1, dtype: int64

# %%
df_train.loc[df_train['v18q']==0,'v18q1'].value_counts()
# Out:
# Series([], Name: v18q1, dtype: int64)

# %%
df_train['v18q1'].fillna(0,inplace=True)
df_test['v18q1'].fillna(0,inplace=True)

# %%
df_train['tipovivi3'].value_counts()
# Out:
# 0    7821
# 1    1736
# Name: tipovivi3, dtype: int64

# %%
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 1, 'v2a1'], label='Monthly rent payment of household(rented=1)')
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 0, 'v2a1'], label='Monthly rent payment of household(rented=0)')
plt.xscale('log')
plt.show()

# %%
df_train['v2a1'].fillna(0,inplace=True)
df_test['v2a1'].fillna(0, inplace=True)

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#                  Total  Percent
# edjef             9557    100.0
# Target               0      0.0
# sanitario3           0      0.0
# sanitario2           0      0.0
# sanitario1           0      0.0
# coopele              0      0.0
# noelec               0      0.0
# planpri              0      0.0
# public               0      0.0
# abastaguano          0      0.0
# abastaguafuera       0      0.0
# abastaguadentro      0      0.0
# cielorazo            0      0.0
# techootro            0      0.0
# techocane            0      0.0
# techoentrepiso       0      0.0
# techozinc            0      0.0
# sanitario5           0      0.0
# sanitario6           0      0.0
# energcocinar1        0      0.0

# %%
total = df_test.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_test.isnull().sum() / df_test.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#                  Total  Percent
# edjef            23856    100.0
# abastaguano          0      0.0
# sanitario2           0      0.0
# sanitario1           0      0.0
# coopele              0      0.0
# noelec               0      0.0
# planpri              0      0.0
# public               0      0.0
# abastaguafuera       0      0.0
# sanitario5           0      0.0
# abastaguadentro      0      0.0
# cielorazo            0      0.0
# techootro            0      0.0
# techocane            0      0.0
# techoentrepiso       0      0.0
# techozinc            0      0.0
# sanitario3           0      0.0
# sanitario6           0      0.0
# pisonotiene          0      0.0
# elimbasu5            0      0.0

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ## 2.1 Object features

# %%
features_object = [col for col in df_train.columns if df_train[col].dtype=='object']

# %%
features_object
# Out:
# ['Id', 'idhogar', 'dependency', 'edjefe', 'edjefa']

# %% [markdown]
# ### dependecy

# %%
# some dependencies are Na, fill those with the square root of the square
df_train['dependency'] = np.sqrt(df_train['SQBdependency'])
df_test['dependency'] = np.sqrt(df_test['SQBdependency'])

# %%
# df_train['dependency'] = df_train['dependency'].replace({np.inf: 0})
# df_test['dependency'] = df_test['dependency'].replace({np.inf: 0})

# def replace_dependency(x):
#     if x == 'yes':
#         return 10
#     elif x == 'no':
#         return 0
#     else:
#         return x

# df_train['dependency'] = df_train['dependency'].apply(replace_dependency).astype(float)
# df_test['dependency'] = df_test['dependency'].apply(replace_dependency).astype(float)

# - As you can see, setting yes -> 10 and no -> 0 is good choice.
# - At first, fill inf value with 0.

# %% [markdown]
# ### edjefe
# replace yes -> 1 and no -> 0

# %%
def replace_edjefe(x):
    if x=='yes':
        return 1
    elif x=='no':
        return 0
    else:
        return x
    
df_train['edjefe'] = df_train['edjefe'].apply(replace_edjefe).astype(float)
df_test['edjefe'] = df_test['edjefe'].apply(replace_edjefe).astype(float)

# %% [markdown]
# ### edjefa
# replace yes -> 1 and no -> 0

# %%
def replace_edjefa(x):
    if x=='yes':
        return 1
    elif x=='no':
        return 0
    else:
        return x
    
df_train['edjefa']=df_train['edjefa'].apply(replace_edjefa).astype(float)
df_test['efjefa']=df_test['edjefa'].apply(replace_edjefa).astype(float)

# %%
# create feature with max education of either head of household
df_train['edjef'] = np.max(df_train[['edjefa','edjefe']], axis=1)
df_test['edjef'] = np.max(df_test[['edjefa','edjefe']], axis=1)

# %% [markdown]
# ### roof and electricity

# %%
df_train['roof_waste_material'] = np.nan
df_test['roof_waste_material'] = np.nan
df_train['electricity_other'] = np.nan
df_test['electricity_other'] = np.nan

def fill_roof_exception(x):
    if(x['techozinc']==0) and (x['techoentrepiso']==0) and (x['techocane']==0) and (x['techootro']==0):
        return 1
    else:
        return 0
    
def fill_no_electricity(x):
    if (x['public']==0) and (x['planpri']==0) and (x['noelec']==0) and (x['coopele']==0):
        return 1
    else:
        return 0
    
df_train['roof_waste_material'] = df_train.apply(lambda x: fill_roof_exception(x),axis=1)
df_test['roof_waste_material'] = df_test.apply(lambda x : fill_roof_exception(x), axis=1)
df_train['electricity_other'] = df_train.apply(lambda x:fill_no_electricity(x), axis=1)
df_test['electricity_other'] = df_test.apply(lambda x: fill_no_electricity(x),axis=1)

# %% [markdown]
# ## 2.2 Extract cat features
# According to data scription, there are many binary category features.

# %%
binary_cat_features = [col for col in df_train.columns if df_train[col].value_counts().shape[0] == 2]

# %% [markdown]
# ## 2.3 Make new features using continuous feature

# %%
continuous_features = [col for col in df_train.columns if col not in binary_cat_features]
continuous_features = [col for col in continuous_features if col not in features_object]
continuous_features = [col for col in continuous_features if col not in ['Id', 'Target', 'idhogar']]

# %%
print('There are {} continuous features'.format(len(continuous_features)))
for col in continuous_features:
    print('{} : {}'.format(col, description.loc[description['varname']==col, 'description'].values))
# Out:
# There are 37 continuous features
# v2a1 : [' Monthly rent payment']
# rooms : ['  number of all rooms in the house']
# v18q1 : [' number of tablets household owns']
# r4h1 : [' Males younger than 12 years of age']
# r4h2 : [' Males 12 years of age and older']
# r4h3 : [' Total males in the household']
# r4m1 : [' Females younger than 12 years of age']
# r4m2 : [' Females 12 years of age and older']
# r4m3 : [' Total females in the household']
# r4t1 : [' persons younger than 12 years of age']
# r4t2 : [' persons 12 years of age and older']
# r4t3 : [' Total persons in the household']
# tamhog : [' size of the household']
# tamviv : [' number of persons living in the household']
# escolari : [' years of schooling']
# rez_esc : [' Years behind in school']
# hhsize : [' household size']
# elimbasu5 : [' =1 if rubbish disposal mainly by throwing in river,   creek or sea']
# hogar_nin : [' Number of children 0 to 19 in household']
# hogar_adul : [' Number of adults in household']
# hogar_mayor : [' # of individuals 65+ in the household']
# hogar_total : [' # of total individuals in the household']
# meaneduc : ['average years of education for adults (18+)']
# bedrooms : [' number of bedrooms']
# overcrowding : [' # persons per room']
# qmobilephone : [' # of mobile phones']
# age : [' Age in years']
# SQBescolari : [' escolari squared']
# SQBage : [' age squared']
# SQBhogar_total : [' hogar_total squared']
# SQBedjefe : [' edjefe squared']
# SQBhogar_nin : [' hogar_nin squared']
# SQBovercrowding : [' overcrowding squared']
# SQBdependency : [' dependency squared']
# SQBmeaned : [' meaned squared']
# agesq : [' Age squared']
# edjef : []

# %%
df_train['edjef'].value_counts()
# Out:
# 6.0     2792
# 11.0    1150
# 9.0      723
# 8.0      474
# 15.0     473
# 3.0      459
# 0.0      435
# 7.0      413
# 4.0      400
# 5.0      398
# 14.0     328
# 17.0     278
# 2.0      278
# 16.0     247
# 10.0     207
# 12.0     185
# 13.0     155
# 1.0       65
# 21.0      48
# 18.0      22
# 19.0      18
# 20.0       9
# Name: edjef, dtype: int64

# %%
df_train.drop('tamhog',axis=1, inplace=True)
df_test.drop('tamhog',axis=1,inplace=True)

# %%
df_train['adult'] = df_train['hogar_adul'] - df_train['hogar_mayor']
df_train['dependency_count'] = df_train['hogar_nin'] + df_train['hogar_mayor']
df_train['dependency'] = df_train['dependency_count'] / df_train['adult']
df_train['child_percent'] = df_train['hogar_nin'] / df_train['hogar_total']
df_train['elder_percent'] = df_train['hogar_mayor'] / df_train['hogar_total']
df_train['adult_percent'] = df_train['hogar_adul'] / df_train['hogar_total']
df_train['males_younger_12_years_percent'] = df_train['r4h1'] / df_train['hogar_total']
df_train['males_older_12_years_percent'] = df_train['r4h2'] / df_train['hogar_total']
df_train['males_percent'] = df_train['r4h3'] / df_train['hogar_total']
df_train['females_younger_12_years_percent'] = df_train['r4m1'] / df_train['hogar_total']
df_train['females_older_12_years_percent'] = df_train['r4m2'] / df_train['hogar_total']
df_train['females_percent'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_percent'] = df_train['r4t1'] / df_train['hogar_total']
df_train['persons_older_12_years_percent'] = df_train['r4t2'] / df_train['hogar_total']
df_train['persons_percent'] = df_train['r4t3'] / df_train['hogar_total']

# %%
df_test['adult'] = df_test['hogar_adul'] - df_test['hogar_mayor']
df_test['dependency_count'] = df_test['hogar_nin'] + df_test['hogar_mayor']
df_test['dependency'] = df_test['dependency_count'] / df_test['adult']
df_test['child_percent'] = df_test['hogar_nin'] / df_test['hogar_total']
df_test['elder_percent'] = df_test['hogar_mayor'] / df_test['hogar_total']
df_test['adult_percent'] = df_test['hogar_adul'] / df_test['hogar_total']
df_test['males_younger_12_years_percent'] = df_test['r4h1'] / df_test['hogar_total']
df_test['males_older_12_years_percent'] = df_test['r4h2'] / df_test['hogar_total']
df_test['males_percent'] = df_test['r4h3'] / df_test['hogar_total']
df_test['females_younger_12_years_percent'] = df_test['r4m1'] / df_test['hogar_total']
df_test['females_older_12_years_percent'] = df_test['r4m2'] / df_test['hogar_total']
df_test['females_percent'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_percent'] = df_test['r4t1'] / df_test['hogar_total']
df_test['persons_older_12_years_percent'] = df_test['r4t2'] / df_test['hogar_total']
df_test['persons_percent'] = df_test['r4t3'] / df_test['hogar_total']

# %%
df_test['males_younger_12_years_in_household_size'] = df_test['r4h1'] / df_test['hhsize']
df_test['males_older_12_years_in_household_size'] = df_test['r4h2'] / df_test['hhsize']
df_test['males_in_household_size'] = df_test['r4h3'] / df_test['hhsize']
df_test['females_younger_12_years_in_household_size'] = df_test['r4m1'] / df_test['hhsize']
df_test['females_older_12_years_in_household_size'] = df_test['r4m2'] / df_test['hhsize']
df_test['females_in_household_size'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_in_household_size'] = df_test['r4t1'] / df_test['hhsize']
df_test['persons_older_12_years_in_household_size'] = df_test['r4t2'] / df_test['hhsize']
df_test['persons_in_household_size'] = df_test['r4t3'] / df_test['hhsize']

# %%
df_test['males_younger_12_years_in_household_size'] = df_test['r4h1'] / df_test['hhsize']
df_test['males_older_12_years_in_household_size'] = df_test['r4h2'] / df_test['hhsize']
df_test['males_in_household_size'] = df_test['r4h3'] / df_test['hhsize']
df_test['females_younger_12_years_in_household_size'] = df_test['r4m1'] / df_test['hhsize']
df_test['females_older_12_years_in_household_size'] = df_test['r4m2'] / df_test['hhsize']
df_test['females_in_household_size'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_in_household_size'] = df_test['r4t1'] / df_test['hhsize']
df_test['persons_older_12_years_in_household_size'] = df_test['r4t2'] / df_test['hhsize']
df_test['persons_in_household_size'] = df_test['r4t3'] / df_test['hhsize']

# %%
df_train['overcrowding_room_and_bedroom'] = (df_train['hacdor'] + df_train['hacapo'])/2
df_test['overcrowding_room_and_bedroom'] = (df_test['hacdor'] + df_test['hacapo'])/2

# %%
df_train['escolari_age'] = df_train['escolari']/df_train['age']
df_test['escolari_age'] = df_test['escolari']/df_test['age']

df_train['age_12_19'] = df_train['hogar_nin'] - df_train['r4t1']
df_test['age_12_19'] = df_test['hogar_nin'] - df_test['r4t1']

# %%
df_train['phones-per-capita'] = df_train['qmobilephone'] / df_train['tamviv']
df_train['tablets-per-capita'] = df_train['v18q1'] / df_train['tamviv']
df_train['rooms-per-capita'] = df_train['rooms'] / df_train['tamviv']
df_train['rent-per-capita'] = df_train['v2a1'] / df_train['tamviv']

# %%
df_test['phones-per-capita'] = df_test['qmobilephone'] / df_test['tamviv']
df_test['tablets-per-capita'] = df_test['v18q1'] / df_test['tamviv']
df_test['rooms-per-capita'] = df_test['rooms'] / df_test['tamviv']
df_test['rent-per-capita'] = df_test['v2a1'] / df_test['tamviv']

# %%
(df_train['hogar_total'] == df_train['r4t3']).sum()
# Out:
# 9509

# %% [markdown]
# ### Rent per family features

# %%
family_size_features = ['adult', 'hogar_adul', 'hogar_mayor', 'hogar_nin', 'hogar_total', 'r4h1', 
                        'r4h2', 'r4h3', 'r4m1', 'r4m2', 'r4m3', 'r4t1', 'r4t2', 'r4t3', 'hhsize']
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v2a1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v2a1'] / df_train[col]
    df_test[new_col_name] = df_test['v2a1'] / df_test[col]

# %%
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### Room per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rooms', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['rooms'] / df_train[col]
    df_test[new_col_name] = df_test['rooms'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### BedRoom per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('bedrooms', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['bedrooms'] / df_train[col]
    df_test[new_col_name] = df_test['bedrooms'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 211) (23856, 220)

# %% [markdown]
# ### Tabulet per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v18q1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v18q1'] / df_train[col]
    df_test[new_col_name] = df_test['v18q1'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### phone per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('qmobilephone', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['qmobilephone'] / df_train[col]
    df_test[new_col_name] = df_test['qmobilephone'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### rez_esc(Years behind in school) per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rez_esc', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['rez_esc'] / df_train[col]
    df_test[new_col_name] = df_test['rez_esc'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %%
df_train['rez_esc_age'] = df_train['rez_esc'] / df_train['age']
df_train['rez_esc_escolari'] = df_train['rez_esc'] / df_train['escolari']

df_test['rez_esc_age'] = df_test['rez_esc'] / df_test['age']
df_test['rez_esc_escolari'] = df_test['rez_esc'] / df_test['escolari']

# %% [markdown]
# ### Rich features

# %%
df_train['tabulet_x_qmobilephone'] = df_train['v18q1'] * df_train['qmobilephone']
df_test['tabulet_x_qmobilephone'] = df_test['v18q1'] * df_test['qmobilephone']

# %%
# wall and roof
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]
        
# wall and floor
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# roof and floor
for col1 in ['etecho1', 'etecho2', 'etecho3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        for col3 in ['eviv1', 'eviv2', 'eviv3']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_train[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 313) (23856, 322)

# %%
for col1 in ['public', 'planpri', 'noelec', 'coopele']:
    for col2 in ['energcocinar1', 'energcocinar2', 'energcocinar3', 'energcocinar4']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
    for col2 in ['elimbasu1', 'elimbasu2', 'elimbasu3', 'elimbasu4', 'elimbasu5', 'elimbasu6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
for col1 in ['abastaguadentro', 'abastaguafuera', 'abastaguano']:
    for col2 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 374) (23856, 383)

# %% [markdown]
# #### i want mix education and area featrues -> education_zone_features

# %%
for col1 in ['area1', 'area2']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# #### Mix region and education

# %%
for col1 in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 446) (23856, 455)

# %%
df_train['electronics'] = df_train['computer'] * df_train['mobilephone'] * df_train['television'] * df_train['v18q'] * df_train['refrig']
df_test['electronics'] = df_test['computer'] * df_test['mobilephone'] * df_test['television'] * df_test['v18q'] * df_test['refrig']

df_train['no_appliances'] = df_train['refrig'] + df_train['computer'] + df_train['television'] + df_train['mobilephone']
df_test['no_appliances'] = df_test['refrig'] + df_test['computer'] + df_test['television'] + df_test['mobilephone']

# %%
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]
        
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]        
        
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        for col3 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_train[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 744) (23856, 753)

# %% [markdown]
# ### Remove feature with only one value

# %%
cols_with_only_one_value = []
for col in df_train.columns:
    if col == 'Target':
        continue
    if df_train[col].value_counts().shape[0] == 1 or df_test[col].value_counts().shape[0] == 1:
        print(col)
        cols_with_only_one_value.append(col)
# Out:
# elimbasu5
# new_planpri_x_energcocinar1
# new_planpri_x_energcocinar2
# new_planpri_x_energcocinar3
# new_planpri_x_energcocinar4
# new_noelec_x_energcocinar2
# new_sanitario1_x_elimbasu4
# new_sanitario1_x_elimbasu5
# new_sanitario1_x_elimbasu6
# new_sanitario2_x_elimbasu4
# new_sanitario2_x_elimbasu5
# new_sanitario2_x_elimbasu6
# new_sanitario3_x_elimbasu5
# new_sanitario5_x_elimbasu4
# new_sanitario5_x_elimbasu5
# new_sanitario5_x_elimbasu6
# new_sanitario6_x_elimbasu2
# new_sanitario6_x_elimbasu4
# new_sanitario6_x_elimbasu5
# new_sanitario6_x_elimbasu6
# new_abastaguafuera_x_sanitario6
# new_abastaguano_x_sanitario2
# new_abastaguano_x_sanitario6
# new_paredblolad_x_pisonatur
# new_paredblolad_x_pisonotiene
# new_paredzocalo_x_pisoother
# new_paredzocalo_x_pisonatur
# new_paredpreb_x_pisonatur
# new_pareddes_x_pisoother
# new_pareddes_x_pisonatur
# new_paredmad_x_pisoother
# new_paredmad_x_pisonatur
# new_paredzinc_x_pisoother
# new_paredzinc_x_pisonatur
# new_paredfibras_x_pisoother
# new_paredfibras_x_pisonatur
# new_paredfibras_x_pisonotiene
# new_paredfibras_x_pisomadera
# new_paredother_x_pisoother
# new_paredother_x_pisonatur
# new_paredother_x_pisonotiene
# new_paredother_x_pisomadera
# new_pisocemento_x_techocane
# new_pisocemento_x_techootro
# new_pisoother_x_techoentrepiso
# new_pisoother_x_techocane
# new_pisoother_x_techootro
# new_pisonatur_x_techozinc
# new_pisonatur_x_techoentrepiso
# new_pisonatur_x_techocane
# new_pisonatur_x_techootro
# new_pisonotiene_x_techoentrepiso
# new_pisonotiene_x_techocane
# new_pisonotiene_x_techootro
# new_pisomadera_x_techocane
# new_pisomadera_x_techootro
# new_paredzocalo_x_techoentrepiso
# new_paredzocalo_x_techocane
# new_paredzocalo_x_techootro
# new_paredpreb_x_techootro
# new_pareddes_x_techoentrepiso
# new_pareddes_x_techocane
# new_pareddes_x_techootro
# new_paredmad_x_techocane
# new_paredmad_x_techootro
# new_paredzinc_x_techoentrepiso
# new_paredzinc_x_techocane
# new_paredzinc_x_techootro
# new_paredfibras_x_techoentrepiso
# new_paredfibras_x_techootro
# new_paredother_x_techoentrepiso
# new_paredother_x_techocane
# new_paredother_x_techootro
# new_paredblolad_x_pisocemento_x_techocane
# new_paredblolad_x_pisocemento_x_techootro
# new_paredblolad_x_pisoother_x_techoentrepiso
# new_paredblolad_x_pisoother_x_techocane
# new_paredblolad_x_pisoother_x_techootro
# new_paredblolad_x_pisonatur_x_techozinc
# new_paredblolad_x_pisonatur_x_techoentrepiso
# new_paredblolad_x_pisonatur_x_techocane
# new_paredblolad_x_pisonatur_x_techootro
# new_paredblolad_x_pisonotiene_x_techozinc
# new_paredblolad_x_pisonotiene_x_techoentrepiso
# new_paredblolad_x_pisonotiene_x_techocane
# new_paredblolad_x_pisonotiene_x_techootro
# new_paredblolad_x_pisomadera_x_techocane
# new_paredblolad_x_pisomadera_x_techootro
# new_paredzocalo_x_pisomoscer_x_techoentrepiso
# new_paredzocalo_x_pisomoscer_x_techocane
# new_paredzocalo_x_pisomoscer_x_techootro
# new_paredzocalo_x_pisocemento_x_techoentrepiso
# new_paredzocalo_x_pisocemento_x_techocane
# new_paredzocalo_x_pisocemento_x_techootro
# new_paredzocalo_x_pisoother_x_techozinc
# new_paredzocalo_x_pisoother_x_techoentrepiso
# new_paredzocalo_x_pisoother_x_techocane
# new_paredzocalo_x_pisoother_x_techootro
# new_paredzocalo_x_pisonatur_x_techozinc
# new_paredzocalo_x_pisonatur_x_techoentrepiso
# new_paredzocalo_x_pisonatur_x_techocane
# new_paredzocalo_x_pisonatur_x_techootro
# new_paredzocalo_x_pisonotiene_x_techoentrepiso
# new_paredzocalo_x_pisonotiene_x_techocane
# new_paredzocalo_x_pisonotiene_x_techootro
# new_paredzocalo_x_pisomadera_x_techoentrepiso
# new_paredzocalo_x_pisomadera_x_techocane
# new_paredzocalo_x_pisomadera_x_techootro
# new_paredpreb_x_pisocemento_x_techoentrepiso
# new_paredpreb_x_pisocemento_x_techocane
# new_paredpreb_x_pisocemento_x_techootro
# new_paredpreb_x_pisoother_x_techoentrepiso
# new_paredpreb_x_pisoother_x_techocane
# new_paredpreb_x_pisoother_x_techootro
# new_paredpreb_x_pisonatur_x_techozinc
# new_paredpreb_x_pisonatur_x_techoentrepiso
# new_paredpreb_x_pisonatur_x_techocane
# new_paredpreb_x_pisonatur_x_techootro
# new_paredpreb_x_pisonotiene_x_techozinc
# new_paredpreb_x_pisonotiene_x_techoentrepiso
# new_paredpreb_x_pisonotiene_x_techocane
# new_paredpreb_x_pisonotiene_x_techootro
# new_paredpreb_x_pisomadera_x_techoentrepiso
# new_paredpreb_x_pisomadera_x_techocane
# new_paredpreb_x_pisomadera_x_techootro
# new_pareddes_x_pisomoscer_x_techozinc
# new_pareddes_x_pisomoscer_x_techoentrepiso
# new_pareddes_x_pisomoscer_x_techocane
# new_pareddes_x_pisomoscer_x_techootro
# new_pareddes_x_pisocemento_x_techoentrepiso
# new_pareddes_x_pisocemento_x_techocane
# new_pareddes_x_pisocemento_x_techootro
# new_pareddes_x_pisoother_x_techozinc
# new_pareddes_x_pisoother_x_techoentrepiso
# new_pareddes_x_pisoother_x_techocane
# new_pareddes_x_pisoother_x_techootro
# new_pareddes_x_pisonatur_x_techozinc
# new_pareddes_x_pisonatur_x_techoentrepiso
# new_pareddes_x_pisonatur_x_techocane
# new_pareddes_x_pisonatur_x_techootro
# new_pareddes_x_pisonotiene_x_techoentrepiso
# new_pareddes_x_pisonotiene_x_techocane
# new_pareddes_x_pisonotiene_x_techootro
# new_pareddes_x_pisomadera_x_techozinc
# new_pareddes_x_pisomadera_x_techoentrepiso
# new_pareddes_x_pisomadera_x_techocane
# new_pareddes_x_pisomadera_x_techootro
# new_paredmad_x_pisomoscer_x_techocane
# new_paredmad_x_pisomoscer_x_techootro
# new_paredmad_x_pisocemento_x_techoentrepiso
# new_paredmad_x_pisocemento_x_techocane
# new_paredmad_x_pisocemento_x_techootro
# new_paredmad_x_pisoother_x_techozinc
# new_paredmad_x_pisoother_x_techoentrepiso
# new_paredmad_x_pisoother_x_techocane
# new_paredmad_x_pisoother_x_techootro
# new_paredmad_x_pisonatur_x_techozinc
# new_paredmad_x_pisonatur_x_techoentrepiso
# new_paredmad_x_pisonatur_x_techocane
# new_paredmad_x_pisonatur_x_techootro
# new_paredmad_x_pisonotiene_x_techoentrepiso
# new_paredmad_x_pisonotiene_x_techocane
# new_paredmad_x_pisonotiene_x_techootro
# new_paredmad_x_pisomadera_x_techocane
# new_paredzinc_x_pisomoscer_x_techoentrepiso
# new_paredzinc_x_pisomoscer_x_techocane
# new_paredzinc_x_pisomoscer_x_techootro
# new_paredzinc_x_pisocemento_x_techoentrepiso
# new_paredzinc_x_pisocemento_x_techocane
# new_paredzinc_x_pisocemento_x_techootro
# new_paredzinc_x_pisoother_x_techozinc
# new_paredzinc_x_pisoother_x_techoentrepiso
# new_paredzinc_x_pisoother_x_techocane
# new_paredzinc_x_pisoother_x_techootro
# new_paredzinc_x_pisonatur_x_techozinc
# new_paredzinc_x_pisonatur_x_techoentrepiso
# new_paredzinc_x_pisonatur_x_techocane
# new_paredzinc_x_pisonatur_x_techootro
# new_paredzinc_x_pisonotiene_x_techoentrepiso
# new_paredzinc_x_pisonotiene_x_techocane
# new_paredzinc_x_pisonotiene_x_techootro
# new_paredzinc_x_pisomadera_x_techoentrepiso
# new_paredzinc_x_pisomadera_x_techocane
# new_paredzinc_x_pisomadera_x_techootro
# new_paredfibras_x_pisomoscer_x_techoentrepiso
# new_paredfibras_x_pisomoscer_x_techocane
# new_paredfibras_x_pisomoscer_x_techootro
# new_paredfibras_x_pisocemento_x_techoentrepiso
# new_paredfibras_x_pisocemento_x_techocane
# new_paredfibras_x_pisocemento_x_techootro
# new_paredfibras_x_pisoother_x_techozinc
# new_paredfibras_x_pisoother_x_techoentrepiso
# new_paredfibras_x_pisoother_x_techocane
# new_paredfibras_x_pisoother_x_techootro
# new_paredfibras_x_pisonatur_x_techozinc
# new_paredfibras_x_pisonatur_x_techoentrepiso
# new_paredfibras_x_pisonatur_x_techocane
# new_paredfibras_x_pisonatur_x_techootro
# new_paredfibras_x_pisonotiene_x_techozinc
# new_paredfibras_x_pisonotiene_x_techoentrepiso
# new_paredfibras_x_pisonotiene_x_techocane
# new_paredfibras_x_pisonotiene_x_techootro
# new_paredfibras_x_pisomadera_x_techozinc
# new_paredfibras_x_pisomadera_x_techoentrepiso
# new_paredfibras_x_pisomadera_x_techocane
# new_paredfibras_x_pisomadera_x_techootro
# new_paredother_x_pisomoscer_x_techozinc
# new_paredother_x_pisomoscer_x_techoentrepiso
# new_paredother_x_pisomoscer_x_techocane
# new_paredother_x_pisomoscer_x_techootro
# new_paredother_x_pisocemento_x_techoentrepiso
# new_paredother_x_pisocemento_x_techocane
# new_paredother_x_pisocemento_x_techootro
# new_paredother_x_pisoother_x_techozinc
# new_paredother_x_pisoother_x_techoentrepiso
# new_paredother_x_pisoother_x_techocane
# new_paredother_x_pisoother_x_techootro
# new_paredother_x_pisonatur_x_techozinc
# new_paredother_x_pisonatur_x_techoentrepiso
# new_paredother_x_pisonatur_x_techocane
# new_paredother_x_pisonatur_x_techootro
# new_paredother_x_pisonotiene_x_techozinc
# new_paredother_x_pisonotiene_x_techoentrepiso
# new_paredother_x_pisonotiene_x_techocane
# new_paredother_x_pisonotiene_x_techootro
# new_paredother_x_pisomadera_x_techozinc
# new_paredother_x_pisomadera_x_techoentrepiso
# new_paredother_x_pisomadera_x_techocane
# new_paredother_x_pisomadera_x_techootro

# %%
df_train.drop(cols_with_only_one_value, axis=1, inplace=True)
df_test.drop(cols_with_only_one_value, axis=1, inplace=True)

# %% [markdown]
# ### Check whether both train and test have same features

# %%
cols_train = np.array(sorted([col for col in df_train.columns if col != 'Target']))
cols_test = np.array(sorted(df_test.columns))

# %%
np.sum(np.array_equal(cols_test,cols_train)) == len(cols_train)
# Out:
# False

# %% [markdown]
# ## 2.4 aggregation features

# %% [markdown]
# In this competition, each samples are member of spectific household(idhogar). So let's aggregate based on 'idhogar' values.

# %% [markdown]
# ### Aggregation for family features

# %%
def max_min(x):
    return x.max() - x.min()

# %%
agg_train = pd.DataFrame()
agg_test = pd.DataFrame()

for item in tqdm(family_size_features):
    for i, function in enumerate(['mean','std','min','max','sum', 'count', max_min]):
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        if i == 6:
            new_col = item + '_new_' + 'max_min'
        else:
            new_col = item + '_new_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test

print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:09<00:00,  1.61it/s]
# new aggregate train set has 2988 rows, and 105 features
# new aggregate test set has 7352 rows, and 105 features

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 
                  'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 
                  'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 
                  'parentesco11', 'parentesco12',
                  'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9',
                 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone',
            'area1', 'area2', 'v18q', 'edjef']



for item in tqdm(aggr_list):
    for function in ['count', 'sum']:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        new_col = item + '_new1_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test
print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 47/47 [00:01<00:00, 41.34it/s]
# new aggregate train set has 2988 rows, and 199 features
# new aggregate test set has 7352 rows, and 199 features

# %%
aggr_list = ['escolari', 'age', 'escolari_age', 'dependency', 'bedrooms', 'overcrowding', 'rooms', 'qmobilephone', 'v18q1']

for item in tqdm(aggr_list):
    for function in ['mean','std','min','max','sum', 'count', max_min]:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        if i == 6:
            new_col = item + '_new2_' + 'max_min'
        else:
            new_col = item + '_new2_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test

print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:05<00:00,  1.65it/s]
# new aggregate train set has 2988 rows, and 208 features
# new aggregate test set has 7352 rows, and 208 features

# %%
agg_test = agg_test.reset_index()
agg_train = agg_train.reset_index()

train_agg = pd.merge(df_train, agg_train, on='idhogar')
test = pd.merge(df_test, agg_test, on='idhogar')

#fill all na as 0
train_agg.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 723) test shape: (23856, 732)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 
                  'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 
                  'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 
                  'parentesco11', 'parentesco12',
                  'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9',
                 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone',
            'area1', 'area2', 'v18q', 'edjef']
    
for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
    
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 1005) test shape: (23856, 1014)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 
                  'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 
                  'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 
                  'parentesco11', 'parentesco12',
                  'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9',
                 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone',
            'area1', 'area2', 'v18q', 'edjef']
    
for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
    
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 1287) test shape: (23856, 1296)

# %%
cols_nums = ['age', 'meaneduc', 'dependency', 
             'hogar_nin', 'hogar_adul', 'hogar_mayor', 'hogar_total',
             'bedrooms', 'overcrowding']

for function in tqdm(['mean','std','min','max','sum', 'count', max_min]):
    for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
        group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_train.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_train][2:]

        group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_test.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_test][2:]

        train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
        test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
        
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [02:33<00:00, 21.98s/it]
# train shape: (9557, 3261) test shape: (23856, 3270)

# %%
train = train_agg.query('parentesco1==1')

# %%
train['dependency'].replace(np.inf, 0, inplace=True)
test['dependency'].replace(np.inf, 0, inplace=True)

# %%
submission = test[['Id']]

#Remove useless feature to reduce dimension
train.drop(columns=['idhogar','Id', 'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace=True)
test.drop(columns=['idhogar','Id',  'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace=True)

correlation = train.corr()
correlation = correlation['Target'].sort_values(ascending=False)

# %%
print('final_data size', train.shape, test.shape)
# Out:
# final_data size (2973, 3249) (23856, 3258)

# %%
print(f'The most 20 positive feature: \n{correlation.head(40)}')
# Out:
# The most 20 positive feature:
# Target                                1.000000
# new5_lugar3_idhogar_edjef_max         0.334254
# new5_lugar4_idhogar_edjef_max         0.334254
# new5_lugar6_idhogar_edjef_max         0.334254
# new5_lugar5_idhogar_edjef_max         0.334254
# new5_lugar2_idhogar_edjef_max         0.334254
# new5_lugar1_idhogar_edjef_max         0.334254
# new5_lugar2_idhogar_edjef_mean        0.333873
# new5_lugar4_idhogar_edjef_mean        0.333873
# new5_lugar1_idhogar_edjef_mean        0.333873
# new5_lugar5_idhogar_edjef_mean        0.333873
# new5_lugar6_idhogar_edjef_mean        0.333873
# new5_lugar3_idhogar_edjef_mean        0.333873
# edjef                                 0.333791
# new5_lugar5_idhogar_edjef_min         0.333791
# new5_lugar1_idhogar_edjef_min         0.333791
# new5_lugar2_idhogar_edjef_min         0.333791
# new5_lugar3_idhogar_edjef_min         0.333791
# new5_lugar6_idhogar_edjef_min         0.333791
# new5_lugar4_idhogar_edjef_min         0.333791
# escolari                              0.333791
# meaneduc                              0.331489
# new5_lugar1_idhogar_instlevel8_max    0.317815
# new5_lugar4_idhogar_instlevel8_max    0.317815
# new5_lugar3_idhogar_instlevel8_max    0.317815
# new5_lugar5_idhogar_instlevel8_max    0.317815
# new5_lugar2_idhogar_instlevel8_max    0.317815
# new5_lugar6_idhogar_instlevel8_max    0.317815
# phones-per-capita                     0.299026
# new5_lugar5_idhogar_instlevel8_std    0.298251
# new5_lugar1_idhogar_instlevel8_std    0.298251
# new5_lugar6_idhogar_instlevel8_std    0.298251
# new5_lugar3_idhogar_instlevel8_std    0.298251
# new5_lugar2_idhogar_instlevel8_std    0.298251
# new5_lugar4_idhogar_instlevel8_std    0.298251
# new_epared3_x_eviv3                   0.298196
# cielorazo                             0.295249
# new4_lugar3_idhogar_instlevel8        0.294277
# new5_lugar2_idhogar_instlevel8_sum    0.294277
# new3_lugar6_idhogar_instlevel8        0.294277
# Name: Target, dtype: float64

# %%
print(f'The most 20 negative feature: \n{correlation.tail(20)}')
# Out:
# The most 20 negative feature:
# new5_lugar5_idhogar_television_<function max_min at 0x000002E625CACB80>    NaN
# new5_lugar5_idhogar_mobilephone_<function max_min at 0x000002E625CACB80>   NaN
# new5_lugar5_idhogar_area1_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar5_idhogar_area2_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar5_idhogar_v18q_<function max_min at 0x000002E625CACB80>          NaN
# new5_lugar6_idhogar_epared1_<function max_min at 0x000002E625CACB80>       NaN
# new5_lugar6_idhogar_epared2_<function max_min at 0x000002E625CACB80>       NaN
# new5_lugar6_idhogar_epared3_<function max_min at 0x000002E625CACB80>       NaN
# new5_lugar6_idhogar_etecho1_<function max_min at 0x000002E625CACB80>       NaN
# new5_lugar6_idhogar_etecho2_<function max_min at 0x000002E625CACB80>       NaN
# new5_lugar6_idhogar_etecho3_<function max_min at 0x000002E625CACB80>       NaN
# new5_lugar6_idhogar_eviv1_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar6_idhogar_eviv2_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar6_idhogar_eviv3_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar6_idhogar_refrig_<function max_min at 0x000002E625CACB80>        NaN
# new5_lugar6_idhogar_television_<function max_min at 0x000002E625CACB80>    NaN
# new5_lugar6_idhogar_mobilephone_<function max_min at 0x000002E625CACB80>   NaN
# new5_lugar6_idhogar_area1_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar6_idhogar_area2_<function max_min at 0x000002E625CACB80>         NaN
# new5_lugar6_idhogar_v18q_<function max_min at 0x000002E625CACB80>          NaN
# Name: Target, dtype: float64

# %% [markdown]
# ## 4. Feature selection using shap

# %%
binary_cat_features = [col for col in train.columns if train[col].value_counts().shape[0] == 2]
object_features = ['edjefe', 'edjefa']

categorical_feats = binary_cat_features + object_features

# %%
def evaluate_macroF1_lgb(truth, predictions):  
    # this follows the discussion in https://github.com/Microsoft/LightGBM/issues/1483
    pred_labels = predictions.reshape(len(np.unique(truth)),-1).argmax(axis=0)
    f1 = f1_score(truth, pred_labels, average='macro')
    return ('macroF1', f1, True)

# %%
y = train['Target']
train.drop(columns=['Target'], inplace=True)

# %%
def print_execution_time(start):
    end = time.time()
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    print('*'*20, "Execution ended in {:0>2}h {:0>2}m {:05.2f}s".format(int(hours),int(minutes),seconds), '*'*20)

# %%
def extract_good_features_using_shap_LGB(params, SEED):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'], 
                             learning_rate=params['learning_rate'],  
                             silent=True, 
                             metric='multi_logloss',
                             n_jobs=-1, n_estimators=10000, 
                             class_weight='balanced',
                             colsample_bytree = params['colsample_bytree'], 
                             min_split_gain= params['min_split_gain'], 
                             bagging_freq = params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves = params['num_leaves'], 
                             subsample = params['subsample'],
                             reg_alpha= params['reg_alpha'],
                             reg_lambda= params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                            )

    kfold = 5
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df  = pd.DataFrame()

    for i, (train_index, test_index) in enumerate(kf.split(train, y)):
        print('='*30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = train.iloc[train_index], train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb, categorical_feature=categorical_feats,
                early_stopping_rounds=500, verbose=500)
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df  = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        print_execution_time(start)

    feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
#     feat_importance_df_shap['shap_cumsum'] = feat_importance_df_shap['shap_values'].cumsum() / feat_importance_df_shap['shap_values'].sum()
#     good_features = feat_importance_df_shap.loc[feat_importance_df_shap['shap_cumsum'] < 0.999].feature
    return feat_importance_df_shap

# %%
total_shap_df  = pd.DataFrame()
NUM_ITERATIONS = 50
for SEED in range(NUM_ITERATIONS):
    print('#'*40, '{} of {} iterations'.format(SEED+1, NUM_ITERATIONS), '#' * 40)
    params = {'max_depth': np.random.choice([5, 6, 7, 8, 10, 12, -1]),
             'learning_rate': np.random.rand() * 0.02,
              'colsample_bytree': np.random.rand() * (1 - 0.5) + 0.5,
              'subsample': np.random.rand() * (1 - 0.5) + 0.5,
              'min_split_gain': np.random.rand() * 0.2,
              'num_leaves': np.random.choice([32, 48, 64]),
              'reg_alpha': np.random.rand() * 2,
              'reg_lambda': np.random.rand() *2,
              'bagging_freq': np.random.randint(4) +1,
              'min_child_weight': np.random.randint(100) + 20
             }
    temp_shap_df = extract_good_features_using_shap_LGB(params, SEED)
    total_shap_df = pd.concat([total_shap_df, temp_shap_df])
# Out:
# ######################################## 1 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.918985	training's macroF1: 0.59614	valid_1's multi_logloss: 1.07336	valid_1's macroF1: 0.398766
# [1000]	training's multi_logloss: 0.800921	training's macroF1: 0.653732	valid_1's multi_logloss: 1.07032	valid_1's macroF1: 0.398132
# Early stopping, best iteration is:
# [519]	training's multi_logloss: 0.913224	training's macroF1: 0.596356	valid_1's multi_logloss: 1.06881	valid_1's macroF1: 0.406677
# ******************** Execution ended in 00h 00m 17.41s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.911476	training's macroF1: 0.591667	valid_1's multi_logloss: 1.03502	valid_1's macroF1: 0.400913
# Early stopping, best iteration is:
# [229]	training's multi_logloss: 1.02353	training's macroF1: 0.543696	valid_1's multi_logloss: 1.04475	valid_1's macroF1: 0.429456
# ******************** Execution ended in 00h 00m 10.16s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.909539	training's macroF1: 0.59013	valid_1's multi_logloss: 1.05484	valid_1's macroF1: 0.402286
# Early stopping, best iteration is:
# [408]	training's multi_logloss: 0.939603	training's macroF1: 0.581856	valid_1's multi_logloss: 1.05069	valid_1's macroF1: 0.387614
# ******************** Execution ended in 00h 00m 12.93s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.92591	training's macroF1: 0.586635	valid_1's multi_logloss: 1.06063	valid_1's macroF1: 0.416269
# Early stopping, best iteration is:
# [413]	training's multi_logloss: 0.955816	training's macroF1: 0.570479	valid_1's multi_logloss: 1.06488	valid_1's macroF1: 0.430756
# ******************** Execution ended in 00h 00m 16.01s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=0, random_state=1989 will be ignored. Current value: seed=0
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.920338	training's macroF1: 0.602217	valid_1's multi_logloss: 1.02285	valid_1's macroF1: 0.39917
# Early stopping, best iteration is:
# [113]	training's multi_logloss: 1.12145	training's macroF1: 0.504179	valid_1's multi_logloss: 1.08693	valid_1's macroF1: 0.421668
# ******************** Execution ended in 00h 00m 11.49s ********************
# ######################################## 2 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.26952	training's macroF1: 0.448283	valid_1's multi_logloss: 1.24545	valid_1's macroF1: 0.344746
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 1.38106	training's macroF1: 0.403737	valid_1's multi_logloss: 1.37936	valid_1's macroF1: 0.354182
# ******************** Execution ended in 00h 00m 07.01s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.2819	training's macroF1: 0.432304	valid_1's multi_logloss: 1.24031	valid_1's macroF1: 0.40077
# [1000]	training's multi_logloss: 1.22322	training's macroF1: 0.443974	valid_1's multi_logloss: 1.17132	valid_1's macroF1: 0.402024
# Early stopping, best iteration is:
# [694]	training's multi_logloss: 1.25563	training's macroF1: 0.439819	valid_1's multi_logloss: 1.20759	valid_1's macroF1: 0.411297
# ******************** Execution ended in 00h 00m 16.35s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.27791	training's macroF1: 0.445986	valid_1's multi_logloss: 1.23191	valid_1's macroF1: 0.385655
# [1000]	training's multi_logloss: 1.21719	training's macroF1: 0.454791	valid_1's multi_logloss: 1.15343	valid_1's macroF1: 0.400328
# [1500]	training's multi_logloss: 1.17942	training's macroF1: 0.463787	valid_1's multi_logloss: 1.11271	valid_1's macroF1: 0.416801
# [2000]	training's multi_logloss: 1.15333	training's macroF1: 0.462777	valid_1's multi_logloss: 1.08971	valid_1's macroF1: 0.419924
# [2500]	training's multi_logloss: 1.1335	training's macroF1: 0.470175	valid_1's multi_logloss: 1.07624	valid_1's macroF1: 0.429132
# Early stopping, best iteration is:
# [2293]	training's multi_logloss: 1.14105	training's macroF1: 0.464792	valid_1's multi_logloss: 1.08138	valid_1's macroF1: 0.43641
# ******************** Execution ended in 00h 00m 42.07s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.27867	training's macroF1: 0.42289	valid_1's multi_logloss: 1.24003	valid_1's macroF1: 0.393356
# [1000]	training's multi_logloss: 1.21711	training's macroF1: 0.444349	valid_1's multi_logloss: 1.16728	valid_1's macroF1: 0.396304
# [1500]	training's multi_logloss: 1.17856	training's macroF1: 0.449584	valid_1's multi_logloss: 1.13114	valid_1's macroF1: 0.416355
# [2000]	training's multi_logloss: 1.15241	training's macroF1: 0.465426	valid_1's multi_logloss: 1.11196	valid_1's macroF1: 0.403499
# Early stopping, best iteration is:
# [1536]	training's multi_logloss: 1.17631	training's macroF1: 0.45123	valid_1's multi_logloss: 1.12926	valid_1's macroF1: 0.421131
# ******************** Execution ended in 00h 00m 23.26s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=1, random_state=1989 will be ignored. Current value: seed=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.27982	training's macroF1: 0.428509	valid_1's multi_logloss: 1.23316	valid_1's macroF1: 0.399621
# [1000]	training's multi_logloss: 1.22239	training's macroF1: 0.442542	valid_1's multi_logloss: 1.15754	valid_1's macroF1: 0.417741
# Early stopping, best iteration is:
# [765]	training's multi_logloss: 1.24585	training's macroF1: 0.434331	valid_1's multi_logloss: 1.18735	valid_1's macroF1: 0.42686
# ******************** Execution ended in 00h 00m 17.93s ********************
# ######################################## 3 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0168	training's macroF1: 0.544477	valid_1's multi_logloss: 1.07919	valid_1's macroF1: 0.397376
# Early stopping, best iteration is:
# [149]	training's multi_logloss: 1.14832	training's macroF1: 0.482298	valid_1's multi_logloss: 1.11687	valid_1's macroF1: 0.415847
# ******************** Execution ended in 00h 00m 11.01s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0001	training's macroF1: 0.543693	valid_1's multi_logloss: 1.06391	valid_1's macroF1: 0.397252
# Early stopping, best iteration is:
# [133]	training's multi_logloss: 1.14984	training's macroF1: 0.473605	valid_1's multi_logloss: 1.1138	valid_1's macroF1: 0.414872
# ******************** Execution ended in 00h 00m 09.57s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.01541	training's macroF1: 0.52937	valid_1's multi_logloss: 1.06398	valid_1's macroF1: 0.392641
# [1000]	training's multi_logloss: 0.929772	training's macroF1: 0.569463	valid_1's multi_logloss: 1.05023	valid_1's macroF1: 0.40694
# Early stopping, best iteration is:
# [998]	training's multi_logloss: 0.930001	training's macroF1: 0.571934	valid_1's multi_logloss: 1.05069	valid_1's macroF1: 0.41058
# ******************** Execution ended in 00h 00m 17.97s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.02031	training's macroF1: 0.534005	valid_1's multi_logloss: 1.08238	valid_1's macroF1: 0.395193
# [1000]	training's multi_logloss: 0.930216	training's macroF1: 0.583069	valid_1's multi_logloss: 1.08497	valid_1's macroF1: 0.391935
# Early stopping, best iteration is:
# [551]	training's multi_logloss: 1.00922	training's macroF1: 0.536326	valid_1's multi_logloss: 1.07977	valid_1's macroF1: 0.412659
# ******************** Execution ended in 00h 00m 12.79s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=2, random_state=1989 will be ignored. Current value: seed=2
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.02412	training's macroF1: 0.548644	valid_1's multi_logloss: 1.06501	valid_1's macroF1: 0.381524
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 1.36022	training's macroF1: 0.417814	valid_1's multi_logloss: 1.34775	valid_1's macroF1: 0.396379
# ******************** Execution ended in 00h 00m 08.84s ********************
# ######################################## 4 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.22989	training's macroF1: 0.483973	valid_1's multi_logloss: 1.20861	valid_1's macroF1: 0.388146
# Early stopping, best iteration is:
# [64]	training's multi_logloss: 1.35871	training's macroF1: 0.4492	valid_1's multi_logloss: 1.35185	valid_1's macroF1: 0.397671
# ******************** Execution ended in 00h 00m 13.91s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.22338	training's macroF1: 0.481061	valid_1's multi_logloss: 1.20104	valid_1's macroF1: 0.359995
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 1.37125	training's macroF1: 0.456319	valid_1's multi_logloss: 1.36735	valid_1's macroF1: 0.373284
# ******************** Execution ended in 00h 00m 10.78s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.2324	training's macroF1: 0.493065	valid_1's multi_logloss: 1.19199	valid_1's macroF1: 0.42769
# [1000]	training's multi_logloss: 1.14283	training's macroF1: 0.514945	valid_1's multi_logloss: 1.10786	valid_1's macroF1: 0.443006
# Early stopping, best iteration is:
# [910]	training's multi_logloss: 1.15639	training's macroF1: 0.513107	valid_1's multi_logloss: 1.11897	valid_1's macroF1: 0.443262
# ******************** Execution ended in 00h 00m 27.29s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.22134	training's macroF1: 0.496948	valid_1's multi_logloss: 1.22297	valid_1's macroF1: 0.349138
# Early stopping, best iteration is:
# [340]	training's multi_logloss: 1.26281	training's macroF1: 0.484451	valid_1's multi_logloss: 1.25785	valid_1's macroF1: 0.362786
# ******************** Execution ended in 00h 00m 20.98s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=3, random_state=1989 will be ignored. Current value: seed=3
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23387	training's macroF1: 0.478803	valid_1's multi_logloss: 1.19726	valid_1's macroF1: 0.369922
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 1.38158	training's macroF1: 0.438213	valid_1's multi_logloss: 1.37954	valid_1's macroF1: 0.392542
# ******************** Execution ended in 00h 00m 10.77s ********************
# ######################################## 5 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05875	training's macroF1: 0.51621	valid_1's multi_logloss: 1.10272	valid_1's macroF1: 0.411023
# Early stopping, best iteration is:
# [298]	training's multi_logloss: 1.11396	training's macroF1: 0.487982	valid_1's multi_logloss: 1.12087	valid_1's macroF1: 0.414628
# ******************** Execution ended in 00h 00m 11.13s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.06153	training's macroF1: 0.515065	valid_1's multi_logloss: 1.03701	valid_1's macroF1: 0.423339
# [1000]	training's multi_logloss: 0.981189	training's macroF1: 0.558092	valid_1's multi_logloss: 1.02752	valid_1's macroF1: 0.442932
# Early stopping, best iteration is:
# [982]	training's multi_logloss: 0.983454	training's macroF1: 0.556263	valid_1's multi_logloss: 1.02779	valid_1's macroF1: 0.442932
# ******************** Execution ended in 00h 00m 22.70s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05885	training's macroF1: 0.524216	valid_1's multi_logloss: 1.068	valid_1's macroF1: 0.406047
# [1000]	training's multi_logloss: 0.979782	training's macroF1: 0.568193	valid_1's multi_logloss: 1.06205	valid_1's macroF1: 0.406115
# Early stopping, best iteration is:
# [543]	training's multi_logloss: 1.05008	training's macroF1: 0.529151	valid_1's multi_logloss: 1.0673	valid_1's macroF1: 0.417547
# ******************** Execution ended in 00h 00m 19.67s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05294	training's macroF1: 0.518102	valid_1's multi_logloss: 1.08476	valid_1's macroF1: 0.410488
# [1000]	training's multi_logloss: 0.975298	training's macroF1: 0.551772	valid_1's multi_logloss: 1.07205	valid_1's macroF1: 0.401952
# Early stopping, best iteration is:
# [537]	training's multi_logloss: 1.04512	training's macroF1: 0.518164	valid_1's multi_logloss: 1.08101	valid_1's macroF1: 0.411588
# ******************** Execution ended in 00h 00m 15.14s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=4, random_state=1989 will be ignored. Current value: seed=4
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0454	training's macroF1: 0.516359	valid_1's multi_logloss: 1.10895	valid_1's macroF1: 0.375548
# Early stopping, best iteration is:
# [178]	training's multi_logloss: 1.1586	training's macroF1: 0.475279	valid_1's multi_logloss: 1.14333	valid_1's macroF1: 0.388823
# ******************** Execution ended in 00h 00m 09.98s ********************
# ######################################## 6 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.2069	training's macroF1: 0.472745	valid_1's multi_logloss: 1.15656	valid_1's macroF1: 0.393075
# [1000]	training's multi_logloss: 1.13495	training's macroF1: 0.492273	valid_1's multi_logloss: 1.10038	valid_1's macroF1: 0.39119
# Early stopping, best iteration is:
# [927]	training's multi_logloss: 1.1427	training's macroF1: 0.487657	valid_1's multi_logloss: 1.10485	valid_1's macroF1: 0.404164
# ******************** Execution ended in 00h 00m 20.56s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.21292	training's macroF1: 0.462435	valid_1's multi_logloss: 1.13999	valid_1's macroF1: 0.394813
# [1000]	training's multi_logloss: 1.14338	training's macroF1: 0.478458	valid_1's multi_logloss: 1.07463	valid_1's macroF1: 0.414804
# [1500]	training's multi_logloss: 1.10474	training's macroF1: 0.489038	valid_1's multi_logloss: 1.05348	valid_1's macroF1: 0.408814
# Early stopping, best iteration is:
# [1155]	training's multi_logloss: 1.12962	training's macroF1: 0.481505	valid_1's multi_logloss: 1.06545	valid_1's macroF1: 0.421118
# ******************** Execution ended in 00h 00m 22.63s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20837	training's macroF1: 0.452778	valid_1's multi_logloss: 1.16071	valid_1's macroF1: 0.405612
# [1000]	training's multi_logloss: 1.13889	training's macroF1: 0.471176	valid_1's multi_logloss: 1.10349	valid_1's macroF1: 0.403908
# Early stopping, best iteration is:
# [745]	training's multi_logloss: 1.16804	training's macroF1: 0.462696	valid_1's multi_logloss: 1.12349	valid_1's macroF1: 0.411853
# ******************** Execution ended in 00h 00m 14.73s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20364	training's macroF1: 0.454373	valid_1's multi_logloss: 1.18165	valid_1's macroF1: 0.361197
# Early stopping, best iteration is:
# [302]	training's multi_logloss: 1.25241	training's macroF1: 0.444127	valid_1's multi_logloss: 1.22918	valid_1's macroF1: 0.373849
# ******************** Execution ended in 00h 00m 09.52s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=5, random_state=1989 will be ignored. Current value: seed=5
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20739	training's macroF1: 0.460639	valid_1's multi_logloss: 1.15506	valid_1's macroF1: 0.400302
# Early stopping, best iteration is:
# [150]	training's multi_logloss: 1.31278	training's macroF1: 0.441587	valid_1's multi_logloss: 1.28155	valid_1's macroF1: 0.419317
# ******************** Execution ended in 00h 00m 10.48s ********************
# ######################################## 7 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.907177	training's macroF1: 0.613134	valid_1's multi_logloss: 0.99453	valid_1's macroF1: 0.444142
# [1000]	training's multi_logloss: 0.776982	training's macroF1: 0.68037	valid_1's multi_logloss: 0.977933	valid_1's macroF1: 0.437584
# Early stopping, best iteration is:
# [502]	training's multi_logloss: 0.906435	training's macroF1: 0.613117	valid_1's multi_logloss: 0.994745	valid_1's macroF1: 0.449975
# ******************** Execution ended in 00h 00m 19.44s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.905657	training's macroF1: 0.615976	valid_1's multi_logloss: 1.01356	valid_1's macroF1: 0.437026
# [1000]	training's multi_logloss: 0.774607	training's macroF1: 0.684832	valid_1's multi_logloss: 0.997369	valid_1's macroF1: 0.449053
# [1500]	training's multi_logloss: 0.689533	training's macroF1: 0.7265	valid_1's multi_logloss: 0.989076	valid_1's macroF1: 0.441601
# Early stopping, best iteration is:
# [1139]	training's multi_logloss: 0.747681	training's macroF1: 0.695801	valid_1's multi_logloss: 0.994668	valid_1's macroF1: 0.451321
# ******************** Execution ended in 00h 00m 24.77s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.895153	training's macroF1: 0.61243	valid_1's multi_logloss: 1.06652	valid_1's macroF1: 0.391678
# [1000]	training's multi_logloss: 0.768966	training's macroF1: 0.678525	valid_1's multi_logloss: 1.06118	valid_1's macroF1: 0.390404
# [1500]	training's multi_logloss: 0.687056	training's macroF1: 0.721898	valid_1's multi_logloss: 1.0564	valid_1's macroF1: 0.401882
# [2000]	training's multi_logloss: 0.628563	training's macroF1: 0.748962	valid_1's multi_logloss: 1.05506	valid_1's macroF1: 0.417029
# [2500]	training's multi_logloss: 0.583709	training's macroF1: 0.767789	valid_1's multi_logloss: 1.05261	valid_1's macroF1: 0.409174
# Early stopping, best iteration is:
# [2018]	training's multi_logloss: 0.626713	training's macroF1: 0.750335	valid_1's multi_logloss: 1.05434	valid_1's macroF1: 0.419267
# ******************** Execution ended in 00h 00m 43.44s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.885092	training's macroF1: 0.615885	valid_1's multi_logloss: 1.09882	valid_1's macroF1: 0.394722
# Early stopping, best iteration is:
# [334]	training's multi_logloss: 0.953121	training's macroF1: 0.586905	valid_1's multi_logloss: 1.09803	valid_1's macroF1: 0.409288
# ******************** Execution ended in 00h 00m 13.03s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=6, random_state=1989 will be ignored. Current value: seed=6
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.898501	training's macroF1: 0.615011	valid_1's multi_logloss: 0.993895	valid_1's macroF1: 0.426879
# [1000]	training's multi_logloss: 0.767067	training's macroF1: 0.683598	valid_1's multi_logloss: 0.987284	valid_1's macroF1: 0.417071
# Early stopping, best iteration is:
# [504]	training's multi_logloss: 0.896927	training's macroF1: 0.615296	valid_1's multi_logloss: 0.994083	valid_1's macroF1: 0.430986
# ******************** Execution ended in 00h 00m 18.28s ********************
# ######################################## 8 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.979625	training's macroF1: 0.582447	valid_1's multi_logloss: 1.04711	valid_1's macroF1: 0.40167
# Early stopping, best iteration is:
# [36]	training's multi_logloss: 1.30236	training's macroF1: 0.495001	valid_1's multi_logloss: 1.27764	valid_1's macroF1: 0.408809
# ******************** Execution ended in 00h 00m 12.05s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.972166	training's macroF1: 0.576026	valid_1's multi_logloss: 1.0557	valid_1's macroF1: 0.378724
# Early stopping, best iteration is:
# [140]	training's multi_logloss: 1.16094	training's macroF1: 0.521534	valid_1's multi_logloss: 1.13906	valid_1's macroF1: 0.403961
# ******************** Execution ended in 00h 00m 12.75s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.988838	training's macroF1: 0.567394	valid_1's multi_logloss: 1.03488	valid_1's macroF1: 0.425891
# Early stopping, best iteration is:
# [282]	training's multi_logloss: 1.07321	training's macroF1: 0.531402	valid_1's multi_logloss: 1.06882	valid_1's macroF1: 0.452278
# ******************** Execution ended in 00h 00m 11.43s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.9777	training's macroF1: 0.579206	valid_1's multi_logloss: 1.02395	valid_1's macroF1: 0.407918
# [1000]	training's multi_logloss: 0.860497	training's macroF1: 0.643673	valid_1's multi_logloss: 1.0105	valid_1's macroF1: 0.408439
# [1500]	training's multi_logloss: 0.782919	training's macroF1: 0.673736	valid_1's multi_logloss: 1.00671	valid_1's macroF1: 0.39984
# Early stopping, best iteration is:
# [1141]	training's multi_logloss: 0.83581	training's macroF1: 0.649473	valid_1's multi_logloss: 1.00901	valid_1's macroF1: 0.419619
# ******************** Execution ended in 00h 00m 27.09s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=7, random_state=1989 will be ignored. Current value: seed=7
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.968732	training's macroF1: 0.578948	valid_1's multi_logloss: 1.05916	valid_1's macroF1: 0.410415
# Early stopping, best iteration is:
# [212]	training's multi_logloss: 1.09838	training's macroF1: 0.537769	valid_1's multi_logloss: 1.10331	valid_1's macroF1: 0.440559
# ******************** Execution ended in 00h 00m 13.51s ********************
# ######################################## 9 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.22721	training's macroF1: 0.448956	valid_1's multi_logloss: 1.18875	valid_1's macroF1: 0.371368
# [1000]	training's multi_logloss: 1.17156	training's macroF1: 0.455909	valid_1's multi_logloss: 1.14269	valid_1's macroF1: 0.383133
# [1500]	training's multi_logloss: 1.14364	training's macroF1: 0.462008	valid_1's multi_logloss: 1.13237	valid_1's macroF1: 0.378125
# Early stopping, best iteration is:
# [1274]	training's multi_logloss: 1.15458	training's macroF1: 0.45679	valid_1's multi_logloss: 1.13455	valid_1's macroF1: 0.39256
# ******************** Execution ended in 00h 00m 18.85s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24364	training's macroF1: 0.43965	valid_1's multi_logloss: 1.16822	valid_1's macroF1: 0.422069
# [1000]	training's multi_logloss: 1.18913	training's macroF1: 0.448115	valid_1's multi_logloss: 1.10708	valid_1's macroF1: 0.411063
# Early stopping, best iteration is:
# [557]	training's multi_logloss: 1.23478	training's macroF1: 0.439959	valid_1's multi_logloss: 1.15692	valid_1's macroF1: 0.427954
# ******************** Execution ended in 00h 00m 11.09s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.22187	training's macroF1: 0.444287	valid_1's multi_logloss: 1.20613	valid_1's macroF1: 0.37983
# [1000]	training's multi_logloss: 1.16346	training's macroF1: 0.459286	valid_1's multi_logloss: 1.16526	valid_1's macroF1: 0.373805
# Early stopping, best iteration is:
# [511]	training's multi_logloss: 1.21994	training's macroF1: 0.44526	valid_1's multi_logloss: 1.20422	valid_1's macroF1: 0.384225
# ******************** Execution ended in 00h 00m 12.55s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23433	training's macroF1: 0.44278	valid_1's multi_logloss: 1.16995	valid_1's macroF1: 0.416028
# [1000]	training's multi_logloss: 1.18225	training's macroF1: 0.458808	valid_1's multi_logloss: 1.11079	valid_1's macroF1: 0.414591
# Early stopping, best iteration is:
# [588]	training's multi_logloss: 1.22142	training's macroF1: 0.443613	valid_1's multi_logloss: 1.1541	valid_1's macroF1: 0.425486
# ******************** Execution ended in 00h 00m 15.36s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=8, random_state=1989 will be ignored. Current value: seed=8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23602	training's macroF1: 0.434059	valid_1's multi_logloss: 1.16419	valid_1's macroF1: 0.355696
# Early stopping, best iteration is:
# [33]	training's multi_logloss: 1.36951	training's macroF1: 0.41578	valid_1's multi_logloss: 1.35778	valid_1's macroF1: 0.402881
# ******************** Execution ended in 00h 00m 06.64s ********************
# ######################################## 10 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.97162	training's macroF1: 0.564548	valid_1's multi_logloss: 1.08235	valid_1's macroF1: 0.40025
# Early stopping, best iteration is:
# [206]	training's multi_logloss: 1.08768	training's macroF1: 0.493001	valid_1's multi_logloss: 1.10167	valid_1's macroF1: 0.424826
# ******************** Execution ended in 00h 00m 11.39s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.963744	training's macroF1: 0.571282	valid_1's multi_logloss: 1.04637	valid_1's macroF1: 0.388254
# Early stopping, best iteration is:
# [199]	training's multi_logloss: 1.08511	training's macroF1: 0.50809	valid_1's multi_logloss: 1.07503	valid_1's macroF1: 0.412438
# ******************** Execution ended in 00h 00m 11.50s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.96797	training's macroF1: 0.569812	valid_1's multi_logloss: 1.07094	valid_1's macroF1: 0.416242
# [1000]	training's multi_logloss: 0.86726	training's macroF1: 0.612771	valid_1's multi_logloss: 1.06952	valid_1's macroF1: 0.415625
# Early stopping, best iteration is:
# [621]	training's multi_logloss: 0.938567	training's macroF1: 0.58501	valid_1's multi_logloss: 1.06915	valid_1's macroF1: 0.429011
# ******************** Execution ended in 00h 00m 21.48s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.971047	training's macroF1: 0.555417	valid_1's multi_logloss: 1.07257	valid_1's macroF1: 0.393416
# Early stopping, best iteration is:
# [298]	training's multi_logloss: 1.03838	training's macroF1: 0.519318	valid_1's multi_logloss: 1.08643	valid_1's macroF1: 0.400411
# ******************** Execution ended in 00h 00m 16.50s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=9, random_state=1989 will be ignored. Current value: seed=9
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.97112	training's macroF1: 0.56334	valid_1's multi_logloss: 1.05164	valid_1's macroF1: 0.378549
# Early stopping, best iteration is:
# [171]	training's multi_logloss: 1.10993	training's macroF1: 0.498662	valid_1's multi_logloss: 1.09217	valid_1's macroF1: 0.401355
# ******************** Execution ended in 00h 00m 10.98s ********************
# ######################################## 11 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.93683	training's macroF1: 0.590762	valid_1's multi_logloss: 1.06603	valid_1's macroF1: 0.410626
# Early stopping, best iteration is:
# [199]	training's multi_logloss: 1.06254	training's macroF1: 0.517735	valid_1's multi_logloss: 1.08669	valid_1's macroF1: 0.41531
# ******************** Execution ended in 00h 00m 11.36s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.9221	training's macroF1: 0.591144	valid_1's multi_logloss: 1.04604	valid_1's macroF1: 0.382049
# Early stopping, best iteration is:
# [92]	training's multi_logloss: 1.15345	training's macroF1: 0.498394	valid_1's multi_logloss: 1.13262	valid_1's macroF1: 0.402253
# ******************** Execution ended in 00h 00m 09.80s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.930973	training's macroF1: 0.591009	valid_1's multi_logloss: 1.03406	valid_1's macroF1: 0.40228
# [1000]	training's multi_logloss: 0.819641	training's macroF1: 0.643315	valid_1's multi_logloss: 1.02198	valid_1's macroF1: 0.414787
# [1500]	training's multi_logloss: 0.74542	training's macroF1: 0.682565	valid_1's multi_logloss: 1.01726	valid_1's macroF1: 0.42242
# Early stopping, best iteration is:
# [1324]	training's multi_logloss: 0.769113	training's macroF1: 0.663899	valid_1's multi_logloss: 1.01815	valid_1's macroF1: 0.429255
# ******************** Execution ended in 00h 00m 33.29s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.925712	training's macroF1: 0.587871	valid_1's multi_logloss: 1.09068	valid_1's macroF1: 0.370187
# Early stopping, best iteration is:
# [91]	training's multi_logloss: 1.15726	training's macroF1: 0.506796	valid_1's multi_logloss: 1.15572	valid_1's macroF1: 0.409053
# ******************** Execution ended in 00h 00m 09.00s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=10, random_state=1989 will be ignored. Current value: seed=10
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.936744	training's macroF1: 0.584645	valid_1's multi_logloss: 1.02961	valid_1's macroF1: 0.414408
# Early stopping, best iteration is:
# [385]	training's multi_logloss: 0.976291	training's macroF1: 0.561826	valid_1's multi_logloss: 1.03477	valid_1's macroF1: 0.438298
# ******************** Execution ended in 00h 00m 13.42s ********************
# ######################################## 12 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=11, random_state=1989 will be ignored. Current value: seed=11
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07513	training's macroF1: 0.494976	valid_1's multi_logloss: 1.1035	valid_1's macroF1: 0.385151
# Early stopping, best iteration is:
# [102]	training's multi_logloss: 1.20936	training's macroF1: 0.453801	valid_1's multi_logloss: 1.16143	valid_1's macroF1: 0.416248
# ******************** Execution ended in 00h 00m 08.07s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=11, random_state=1989 will be ignored. Current value: seed=11
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05995	training's macroF1: 0.518628	valid_1's multi_logloss: 1.08899	valid_1's macroF1: 0.371714
# Early stopping, best iteration is:
# [336]	training's multi_logloss: 1.09314	training's macroF1: 0.500969	valid_1's multi_logloss: 1.09357	valid_1's macroF1: 0.381217
# ******************** Execution ended in 00h 00m 11.50s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=11, random_state=1989 will be ignored. Current value: seed=11
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.06124	training's macroF1: 0.501636	valid_1's multi_logloss: 1.11757	valid_1's macroF1: 0.370414
# Early stopping, best iteration is:
# [364]	training's multi_logloss: 1.08848	training's macroF1: 0.495443	valid_1's multi_logloss: 1.11221	valid_1's macroF1: 0.372081
# ******************** Execution ended in 00h 00m 12.13s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=11, random_state=1989 will be ignored. Current value: seed=11
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08369	training's macroF1: 0.49413	valid_1's multi_logloss: 1.03102	valid_1's macroF1: 0.436412
# Early stopping, best iteration is:
# [266]	training's multi_logloss: 1.1344	training's macroF1: 0.462964	valid_1's multi_logloss: 1.05181	valid_1's macroF1: 0.458053
# ...
# ******************** Execution ended in 00h 00m 37.13s ********************
# ######################################## 47 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.18365	training's macroF1: 0.45849	valid_1's multi_logloss: 1.12717	valid_1's macroF1: 0.392587
# Early stopping, best iteration is:
# [279]	training's multi_logloss: 1.24129	training's macroF1: 0.447202	valid_1's multi_logloss: 1.19153	valid_1's macroF1: 0.405437
# ******************** Execution ended in 00h 00m 10.02s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17705	training's macroF1: 0.469856	valid_1's multi_logloss: 1.13416	valid_1's macroF1: 0.421951
# Early stopping, best iteration is:
# [453]	training's multi_logloss: 1.18791	training's macroF1: 0.470366	valid_1's multi_logloss: 1.14303	valid_1's macroF1: 0.423029
# ******************** Execution ended in 00h 00m 10.97s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.18502	training's macroF1: 0.462723	valid_1's multi_logloss: 1.16292	valid_1's macroF1: 0.379981
# Early stopping, best iteration is:
# [201]	training's multi_logloss: 1.27065	training's macroF1: 0.443056	valid_1's multi_logloss: 1.24523	valid_1's macroF1: 0.395401
# ******************** Execution ended in 00h 00m 10.99s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.18413	training's macroF1: 0.476292	valid_1's multi_logloss: 1.13194	valid_1's macroF1: 0.408013
# [1000]	training's multi_logloss: 1.11914	training's macroF1: 0.492056	valid_1's multi_logloss: 1.08442	valid_1's macroF1: 0.401311
# Early stopping, best iteration is:
# [509]	training's multi_logloss: 1.18243	training's macroF1: 0.477522	valid_1's multi_logloss: 1.13052	valid_1's macroF1: 0.41098
# ******************** Execution ended in 00h 00m 15.81s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=46, random_state=1989 will be ignored. Current value: seed=46
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1828	training's macroF1: 0.464657	valid_1's multi_logloss: 1.11691	valid_1's macroF1: 0.39229
# Early stopping, best iteration is:
# [298]	training's multi_logloss: 1.23347	training's macroF1: 0.446429	valid_1's multi_logloss: 1.17355	valid_1's macroF1: 0.407782
# ******************** Execution ended in 00h 00m 09.65s ********************
# ######################################## 48 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.894367	training's macroF1: 0.617152	valid_1's multi_logloss: 1.01234	valid_1's macroF1: 0.405755
# Early stopping, best iteration is:
# [350]	training's multi_logloss: 0.955983	training's macroF1: 0.586196	valid_1's multi_logloss: 1.02151	valid_1's macroF1: 0.425347
# ******************** Execution ended in 00h 00m 15.03s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.897662	training's macroF1: 0.616201	valid_1's multi_logloss: 1.02859	valid_1's macroF1: 0.404669
# Early stopping, best iteration is:
# [111]	training's multi_logloss: 1.13	training's macroF1: 0.516885	valid_1's multi_logloss: 1.11323	valid_1's macroF1: 0.413981
# ******************** Execution ended in 00h 00m 10.62s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.891219	training's macroF1: 0.623805	valid_1's multi_logloss: 1.03342	valid_1's macroF1: 0.422501
# [1000]	training's multi_logloss: 0.754553	training's macroF1: 0.684009	valid_1's multi_logloss: 1.01848	valid_1's macroF1: 0.426413
# Early stopping, best iteration is:
# [660]	training's multi_logloss: 0.838532	training's macroF1: 0.649993	valid_1's multi_logloss: 1.02726	valid_1's macroF1: 0.44331
# ******************** Execution ended in 00h 00m 26.68s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.882494	training's macroF1: 0.626153	valid_1's multi_logloss: 1.04701	valid_1's macroF1: 0.429091
# [1000]	training's multi_logloss: 0.748498	training's macroF1: 0.686987	valid_1's multi_logloss: 1.03554	valid_1's macroF1: 0.42536
# Early stopping, best iteration is:
# [577]	training's multi_logloss: 0.855498	training's macroF1: 0.640409	valid_1's multi_logloss: 1.0439	valid_1's macroF1: 0.439779
# ******************** Execution ended in 00h 00m 18.83s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=47, random_state=1989 will be ignored. Current value: seed=47
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.876656	training's macroF1: 0.616395	valid_1's multi_logloss: 1.05223	valid_1's macroF1: 0.400066
# [1000]	training's multi_logloss: 0.747803	training's macroF1: 0.689233	valid_1's multi_logloss: 1.05129	valid_1's macroF1: 0.382666
# Early stopping, best iteration is:
# [619]	training's multi_logloss: 0.838502	training's macroF1: 0.639732	valid_1's multi_logloss: 1.04921	valid_1's macroF1: 0.405416
# ******************** Execution ended in 00h 00m 21.04s ********************
# ######################################## 49 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.817001	training's macroF1: 0.657727	valid_1's multi_logloss: 1.05299	valid_1's macroF1: 0.394652
# [1000]	training's multi_logloss: 0.686157	training's macroF1: 0.71424	valid_1's multi_logloss: 1.0471	valid_1's macroF1: 0.39119
# Early stopping, best iteration is:
# [607]	training's multi_logloss: 0.781963	training's macroF1: 0.667534	valid_1's multi_logloss: 1.05102	valid_1's macroF1: 0.407394
# ******************** Execution ended in 00h 00m 23.26s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.828843	training's macroF1: 0.647809	valid_1's multi_logloss: 0.999754	valid_1's macroF1: 0.441834
# [1000]	training's multi_logloss: 0.689943	training's macroF1: 0.718818	valid_1's multi_logloss: 1.00084	valid_1's macroF1: 0.463199
# Early stopping, best iteration is:
# [790]	training's multi_logloss: 0.736861	training's macroF1: 0.699341	valid_1's multi_logloss: 0.999323	valid_1's macroF1: 0.454369
# ******************** Execution ended in 00h 00m 19.68s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.821825	training's macroF1: 0.641305	valid_1's multi_logloss: 0.995227	valid_1's macroF1: 0.425835
# Early stopping, best iteration is:
# [204]	training's multi_logloss: 0.975219	training's macroF1: 0.571513	valid_1's multi_logloss: 1.02416	valid_1's macroF1: 0.446876
# ******************** Execution ended in 00h 00m 11.96s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.824563	training's macroF1: 0.651447	valid_1's multi_logloss: 1.03426	valid_1's macroF1: 0.414626
# Early stopping, best iteration is:
# [267]	training's multi_logloss: 0.934932	training's macroF1: 0.591878	valid_1's multi_logloss: 1.04008	valid_1's macroF1: 0.423174
# ******************** Execution ended in 00h 00m 17.36s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=48, random_state=1989 will be ignored. Current value: seed=48
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.81516	training's macroF1: 0.645443	valid_1's multi_logloss: 1.04958	valid_1's macroF1: 0.401022
# Early stopping, best iteration is:
# [263]	training's multi_logloss: 0.926024	training's macroF1: 0.597087	valid_1's multi_logloss: 1.0612	valid_1's macroF1: 0.415013
# ******************** Execution ended in 00h 00m 14.33s ********************
# ######################################## 50 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.97748	training's macroF1: 0.562323	valid_1's multi_logloss: 1.09795	valid_1's macroF1: 0.359128
# Early stopping, best iteration is:
# [217]	training's multi_logloss: 1.07725	training's macroF1: 0.512964	valid_1's multi_logloss: 1.11048	valid_1's macroF1: 0.377936
# ******************** Execution ended in 00h 00m 09.69s ********************
# ============================== 2 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.982461	training's macroF1: 0.553498	valid_1's multi_logloss: 1.11087	valid_1's macroF1: 0.391859
# [1000]	training's multi_logloss: 0.88721	training's macroF1: 0.604812	valid_1's multi_logloss: 1.10922	valid_1's macroF1: 0.407668
# [1500]	training's multi_logloss: 0.823773	training's macroF1: 0.63911	valid_1's multi_logloss: 1.10951	valid_1's macroF1: 0.405357
# Early stopping, best iteration is:
# [1219]	training's multi_logloss: 0.856756	training's macroF1: 0.618687	valid_1's multi_logloss: 1.1092	valid_1's macroF1: 0.420581
# ******************** Execution ended in 00h 00m 25.59s ********************
# ============================== 3 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00419	training's macroF1: 0.555459	valid_1's multi_logloss: 1.04015	valid_1's macroF1: 0.433045
# Early stopping, best iteration is:
# [400]	training's multi_logloss: 1.03171	training's macroF1: 0.54276	valid_1's multi_logloss: 1.04409	valid_1's macroF1: 0.442948
# ******************** Execution ended in 00h 00m 16.60s ********************
# ============================== 4 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.992515	training's macroF1: 0.53903	valid_1's multi_logloss: 1.06693	valid_1's macroF1: 0.422704
# Early stopping, best iteration is:
# [371]	training's multi_logloss: 1.02878	training's macroF1: 0.527265	valid_1's multi_logloss: 1.06913	valid_1's macroF1: 0.433623
# ******************** Execution ended in 00h 00m 12.21s ********************
# ============================== 5 of 5 folds ==============================
# [LightGBM] [Warning] seed is set=49, random_state=1989 will be ignored. Current value: seed=49
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.98266	training's macroF1: 0.558242	valid_1's multi_logloss: 1.01495	valid_1's macroF1: 0.407569
# [1000]	training's multi_logloss: 0.885403	training's macroF1: 0.605381	valid_1's multi_logloss: 1.01248	valid_1's macroF1: 0.411388
# Early stopping, best iteration is:
# [594]	training's multi_logloss: 0.958965	training's macroF1: 0.566968	valid_1's multi_logloss: 1.01156	valid_1's macroF1: 0.417987
# ******************** Execution ended in 00h 00m 15.13s ********************

# %%
shap_sorted_df = total_shap_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
feat_imp_sorted_df = total_shap_df.groupby('feature').mean().sort_values('feat_imp', ascending=False).reset_index()
features_top_shap = shap_sorted_df['feature'][:500]
features_top_feat_imp = feat_imp_sorted_df['feature'][:500]
top_features = pd.Series(features_top_shap.tolist() + features_top_feat_imp.tolist())
top_features = top_features.unique()

# %% [markdown]
# ## 4. Model development

# %%
new_train = train[top_features].copy()
new_test = test[top_features].copy()

# %%
print('new_train shape:', new_train.shape, 'new_test shape:', new_test.shape)
# Out:
# new_train shape: (2973, 529) new_test shape: (23856, 529)

# %%
new_train['edjefa']=new_train['edjefa'].replace(['no'],0)
new_test['edjefa']=new_test['edjefa'].replace(['no'],0)

new_train['edjefa']=pd.to_numeric( new_train['edjefa'])
new_test['edjefa']=pd.to_numeric(new_test['edjefa'])

# %%
new_categorical_feats = [col for col in top_features if col in categorical_feats]

# %%
def LGB_OOF(params, categorical_feats, N_FOLDs, SEED=1989):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'], 
                             learning_rate=params['learning_rate'],  
                             silent=True, 
                             metric='multi_logloss',
                             n_jobs=-1, n_estimators=10000, 
                             class_weight='balanced',
                             colsample_bytree = params['colsample_bytree'], 
                             min_split_gain= params['min_split_gain'], 
                             bagging_freq = params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves = params['num_leaves'], 
                             subsample = params['subsample'],
                             reg_alpha= params['reg_alpha'],
                             reg_lambda= params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                            )

    kfold = 10
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df  = pd.DataFrame()
    predicts_result = []

    for i, (train_index, test_index) in enumerate(kf.split(new_train, y)):
        print('='*30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = new_train.iloc[train_index], new_train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb,categorical_feature=new_categorical_feats,
                early_stopping_rounds=500, verbose=500)
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df  = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        predicts_result.append(clf.predict(new_test))
        print_execution_time(start)
    return predicts_result, feat_importance_df

# %%
params = {'max_depth': 6,
         'learning_rate': 0.002,
          'colsample_bytree': 0.8,
          'subsample': 0.8,
          'min_split_gain': 0.02,
          'num_leaves': 48,
          'reg_alpha': 0.04,
          'reg_lambda': 0.073,
          'bagging_freq': 2,
          'min_child_weight': 40
         }

N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(params, new_categorical_feats, N_Folds, SEED=1989)
# Out:
# ============================== 1 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13419	training's macroF1: 0.553389	valid_1's multi_logloss: 1.1531	valid_1's macroF1: 0.387546
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 1.35059	training's macroF1: 0.504186	valid_1's multi_logloss: 1.34609	valid_1's macroF1: 0.407925
# ******************** Execution ended in 00h 00m 05.05s ********************
# ============================== 2 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.14284	training's macroF1: 0.526863	valid_1's multi_logloss: 1.0633	valid_1's macroF1: 0.498261
# [1000]	training's multi_logloss: 1.02812	training's macroF1: 0.561169	valid_1's multi_logloss: 0.963159	valid_1's macroF1: 0.486817
# Early stopping, best iteration is:
# [514]	training's multi_logloss: 1.13879	training's macroF1: 0.527471	valid_1's multi_logloss: 1.05912	valid_1's macroF1: 0.505577
# ******************** Execution ended in 00h 00m 14.56s ********************
# ============================== 3 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13654	training's macroF1: 0.546756	valid_1's multi_logloss: 1.11327	valid_1's macroF1: 0.407911
# Early stopping, best iteration is:
# [255]	training's multi_logloss: 1.22894	training's macroF1: 0.512957	valid_1's multi_logloss: 1.20066	valid_1's macroF1: 0.418314
# ******************** Execution ended in 00h 00m 09.95s ********************
# ============================== 4 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13244	training's macroF1: 0.536317	valid_1's multi_logloss: 1.1552	valid_1's macroF1: 0.411612
# [1000]	training's multi_logloss: 1.0141	training's macroF1: 0.578329	valid_1's multi_logloss: 1.09852	valid_1's macroF1: 0.419248
# [1500]	training's multi_logloss: 0.939729	training's macroF1: 0.606798	valid_1's multi_logloss: 1.08315	valid_1's macroF1: 0.416701
# Early stopping, best iteration is:
# [1076]	training's multi_logloss: 1.00094	training's macroF1: 0.584724	valid_1's multi_logloss: 1.09464	valid_1's macroF1: 0.425061
# ******************** Execution ended in 00h 00m 20.70s ********************
# ============================== 5 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13817	training's macroF1: 0.532344	valid_1's multi_logloss: 1.13413	valid_1's macroF1: 0.383873
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38388	training's macroF1: 0.453653	valid_1's multi_logloss: 1.38331	valid_1's macroF1: 0.404651
# ******************** Execution ended in 00h 00m 04.35s ********************
# ============================== 6 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13682	training's macroF1: 0.534683	valid_1's multi_logloss: 1.12081	valid_1's macroF1: 0.412457
# [1000]	training's multi_logloss: 1.0189	training's macroF1: 0.572179	valid_1's multi_logloss: 1.04076	valid_1's macroF1: 0.418855
# [1500]	training's multi_logloss: 0.943601	training's macroF1: 0.610576	valid_1's multi_logloss: 1.01352	valid_1's macroF1: 0.431818
# Early stopping, best iteration is:
# [1179]	training's multi_logloss: 0.988978	training's macroF1: 0.588052	valid_1's multi_logloss: 1.02835	valid_1's macroF1: 0.436014
# ******************** Execution ended in 00h 00m 23.51s ********************
# ============================== 7 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1332	training's macroF1: 0.549291	valid_1's multi_logloss: 1.15889	valid_1's macroF1: 0.386871
# Early stopping, best iteration is:
# [31]	training's multi_logloss: 1.36095	training's macroF1: 0.504457	valid_1's multi_logloss: 1.35952	valid_1's macroF1: 0.407584
# ******************** Execution ended in 00h 00m 05.81s ********************
# ============================== 8 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1324	training's macroF1: 0.546925	valid_1's multi_logloss: 1.14614	valid_1's macroF1: 0.373807
# Early stopping, best iteration is:
# [388]	training's multi_logloss: 1.17093	training's macroF1: 0.539721	valid_1's multi_logloss: 1.17532	valid_1's macroF1: 0.385227
# ******************** Execution ended in 00h 00m 12.44s ********************
# ============================== 9 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13443	training's macroF1: 0.554282	valid_1's multi_logloss: 1.12987	valid_1's macroF1: 0.398371
# Early stopping, best iteration is:
# [234]	training's multi_logloss: 1.23745	training's macroF1: 0.52524	valid_1's multi_logloss: 1.22362	valid_1's macroF1: 0.408057
# ******************** Execution ended in 00h 00m 07.44s ********************
# ============================== 10 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13027	training's macroF1: 0.527624	valid_1's multi_logloss: 1.12294	valid_1's macroF1: 0.368119
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.38087	training's macroF1: 0.469103	valid_1's multi_logloss: 1.37959	valid_1's macroF1: 0.42507
# ******************** Execution ended in 00h 00m 04.40s ********************

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 20))
feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()

num_features = 50
sns.barplot(x=feat_importance_df_shap.shap_values[:num_features], y=feat_importance_df_shap.feature[:num_features], ax=ax[0])
ax[0].set_title('Feature importance based on shap values')

feat_importance_df = feat_importance_df.groupby('feature').mean().sort_values('feat_imp', ascending=False).reset_index()

num_features = 50
sns.barplot(x=feat_importance_df.shap_values[:num_features], y=feat_importance_df.feature[:num_features], ax=ax[1])
ax[1].set_title('Feaure importance based on feature importance from lgbm')
plt.show()

# %%
submission['Target'] = np.array(predicts_result).mean(axis=0).round().astype(int)
submission.to_csv('submission_with_new_feature_set.csv', index = False)

# %% [markdown]
# ### Randomized serach

# %%
optimized_param = None
lowest_cv = 1000
total_iteration = 100
for i in range(total_iteration):
    print('-'*20, 'For {} of {} iterations'.format(i+1, total_iteration), '-'*20)
    learning_rate = np.random.rand() * 0.02
    n_folds = 3

    num_class = len(np.unique(y))

    params = {}
    params['verbosity'] = -1
    params['verbose']=1
    params['application'] = 'multiclass'
    params['metric'] = 'multi_logloss'
    params['num_class'] = num_class
    params['class_weight'] = 'balanced'
    params['num_leaves'] = np.random.randint(24, 48)
    params['max_depth'] = np.random.randint(5, 8)
    params['min_child_weight'] = np.random.randint(5, 50)
    params['min_split_gain'] = np.random.rand() * 0.09
    params['colsample_bytree'] = np.random.rand() * (0.9 - 0.1) + 0.1
    params['subsample'] = np.random.rand() * (1 - 0.8) + 0.8
    params['bagging_freq'] = np.random.randint(1, 5)
    params['bagging_seed'] = np.random.randint(1, 5)
    params['reg_alpha'] = np.random.rand() * 2
    params['reg_lambda'] = np.random.rand() * 2
    params['learning_rate'] = np.random.rand() * 0.02
    params['seed']  =1989

    d_train = lgb.Dataset(data=new_train, label=y.values-1, categorical_feature=new_categorical_feats, free_raw_data=False)
    cv_results = lgb.cv(params=params, train_set=d_train, num_boost_round=10000, categorical_feature=new_categorical_feats,
                        nfold=n_folds, stratified=True, shuffle=True, early_stopping_rounds=1, verbose_eval=1000)

    min_cv_results = min(cv_results['multi_logloss-mean'])

    if min_cv_results < lowest_cv:
        lowest_cv = min_cv_results
        optimized_param = params
# Out:
# -------------------- For 1 of 100 iterations --------------------
# [LightGBM] [Warning] Unknown parameter: class_weight
# [LightGBM] [Warning] verbosity is set=-1, verbose=1 will be ignored. Current value: verbosity=-1
# -------------------- For 2 of 100 iterations --------------------
# -------------------- For 3 of 100 iterations --------------------
# -------------------- For 4 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.931209 + 0.00318498
# [2000]	cv_agg's multi_logloss: 0.889234 + 0.00662914
# [3000]	cv_agg's multi_logloss: 0.864016 + 0.00928873
# [4000]	cv_agg's multi_logloss: 0.848601 + 0.0111882
# [5000]	cv_agg's multi_logloss: 0.839429 + 0.0127917
# [6000]	cv_agg's multi_logloss: 0.833983 + 0.0141512
# -------------------- For 5 of 100 iterations --------------------
# -------------------- For 6 of 100 iterations --------------------
# -------------------- For 7 of 100 iterations --------------------
# -------------------- For 8 of 100 iterations --------------------
# -------------------- For 9 of 100 iterations --------------------
# -------------------- For 10 of 100 iterations --------------------
# -------------------- For 11 of 100 iterations --------------------
# -------------------- For 12 of 100 iterations --------------------
# -------------------- For 13 of 100 iterations --------------------
# -------------------- For 14 of 100 iterations --------------------
# -------------------- For 15 of 100 iterations --------------------
# -------------------- For 16 of 100 iterations --------------------
# -------------------- For 17 of 100 iterations --------------------
# -------------------- For 18 of 100 iterations --------------------
# -------------------- For 19 of 100 iterations --------------------
# -------------------- For 20 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.831754 + 0.0150285
# -------------------- For 21 of 100 iterations --------------------
# -------------------- For 22 of 100 iterations --------------------
# -------------------- For 23 of 100 iterations --------------------
# -------------------- For 24 of 100 iterations --------------------
# -------------------- For 25 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.996732 + 0.000650267
# [2000]	cv_agg's multi_logloss: 0.987394 + 0.000829732
# [3000]	cv_agg's multi_logloss: 0.978687 + 0.00117678
# [4000]	cv_agg's multi_logloss: 0.970527 + 0.00157816
# [5000]	cv_agg's multi_logloss: 0.962882 + 0.00198028
# [6000]	cv_agg's multi_logloss: 0.955692 + 0.00238343
# [7000]	cv_agg's multi_logloss: 0.948952 + 0.00278418
# [8000]	cv_agg's multi_logloss: 0.9426 + 0.00318278
# [9000]	cv_agg's multi_logloss: 0.936614 + 0.00357752
# [10000]	cv_agg's multi_logloss: 0.930962 + 0.00396926
# -------------------- For 26 of 100 iterations --------------------
# -------------------- For 27 of 100 iterations --------------------
# -------------------- For 28 of 100 iterations --------------------
# -------------------- For 29 of 100 iterations --------------------
# -------------------- For 30 of 100 iterations --------------------
# -------------------- For 31 of 100 iterations --------------------
# -------------------- For 32 of 100 iterations --------------------
# -------------------- For 33 of 100 iterations --------------------
# -------------------- For 34 of 100 iterations --------------------
# -------------------- For 35 of 100 iterations --------------------
# -------------------- For 36 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.850673 + 0.0110803
# -------------------- For 37 of 100 iterations --------------------
# -------------------- For 38 of 100 iterations --------------------
# -------------------- For 39 of 100 iterations --------------------
# -------------------- For 40 of 100 iterations --------------------
# -------------------- For 41 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.847425 + 0.0100886
# -------------------- For 42 of 100 iterations --------------------
# -------------------- For 43 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.832177 + 0.014064
# -------------------- For 44 of 100 iterations --------------------
# -------------------- For 45 of 100 iterations --------------------
# -------------------- For 46 of 100 iterations --------------------
# -------------------- For 47 of 100 iterations --------------------
# -------------------- For 48 of 100 iterations --------------------
# -------------------- For 49 of 100 iterations --------------------
# -------------------- For 50 of 100 iterations --------------------
# -------------------- For 51 of 100 iterations --------------------
# -------------------- For 52 of 100 iterations --------------------
# -------------------- For 53 of 100 iterations --------------------
# -------------------- For 54 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.90331 + 0.00613902
# [2000]	cv_agg's multi_logloss: 0.863575 + 0.00999936
# [3000]	cv_agg's multi_logloss: 0.84517 + 0.012152
# [4000]	cv_agg's multi_logloss: 0.836323 + 0.0136406
# -------------------- For 55 of 100 iterations --------------------
# -------------------- For 56 of 100 iterations --------------------
# -------------------- For 57 of 100 iterations --------------------
# -------------------- For 58 of 100 iterations --------------------
# -------------------- For 59 of 100 iterations --------------------
# -------------------- For 60 of 100 iterations --------------------
# -------------------- For 61 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.858073 + 0.00951816
# [2000]	cv_agg's multi_logloss: 0.829955 + 0.0143947
# -------------------- For 62 of 100 iterations --------------------
# -------------------- For 63 of 100 iterations --------------------
# -------------------- For 64 of 100 iterations --------------------
# -------------------- For 65 of 100 iterations --------------------
# -------------------- For 66 of 100 iterations --------------------
# -------------------- For 67 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.842 + 0.0128167
# -------------------- For 68 of 100 iterations --------------------
# -------------------- For 69 of 100 iterations --------------------
# -------------------- For 70 of 100 iterations --------------------
# -------------------- For 71 of 100 iterations --------------------
# -------------------- For 72 of 100 iterations --------------------
# -------------------- For 73 of 100 iterations --------------------
# -------------------- For 74 of 100 iterations --------------------
# -------------------- For 75 of 100 iterations --------------------
# -------------------- For 76 of 100 iterations --------------------
# -------------------- For 77 of 100 iterations --------------------
# -------------------- For 78 of 100 iterations --------------------
# -------------------- For 79 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.903395 + 0.00564839
# [2000]	cv_agg's multi_logloss: 0.859842 + 0.0095734
# [3000]	cv_agg's multi_logloss: 0.840021 + 0.0122001
# [4000]	cv_agg's multi_logloss: 0.831007 + 0.0142706
# -------------------- For 80 of 100 iterations --------------------
# -------------------- For 81 of 100 iterations --------------------
# -------------------- For 82 of 100 iterations --------------------
# -------------------- For 83 of 100 iterations --------------------
# -------------------- For 84 of 100 iterations --------------------
# -------------------- For 85 of 100 iterations --------------------
# -------------------- For 86 of 100 iterations --------------------
# -------------------- For 87 of 100 iterations --------------------
# -------------------- For 88 of 100 iterations --------------------
# -------------------- For 89 of 100 iterations --------------------
# -------------------- For 90 of 100 iterations --------------------
# -------------------- For 91 of 100 iterations --------------------
# -------------------- For 92 of 100 iterations --------------------
# -------------------- For 93 of 100 iterations --------------------
# -------------------- For 94 of 100 iterations --------------------
# [1000]	cv_agg's multi_logloss: 0.882957 + 0.0080293
# [2000]	cv_agg's multi_logloss: 0.845606 + 0.0123469
# -------------------- For 95 of 100 iterations --------------------
# -------------------- For 96 of 100 iterations --------------------
# -------------------- For 97 of 100 iterations --------------------
# -------------------- For 98 of 100 iterations --------------------
# -------------------- For 99 of 100 iterations --------------------
# -------------------- For 100 of 100 iterations --------------------

# %%
N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(optimized_param, new_categorical_feats, N_Folds, SEED=1989)
# Out:
# ============================== 1 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.643484	training's macroF1: 0.771823	valid_1's multi_logloss: 0.987012	valid_1's macroF1: 0.439058
# Early stopping, best iteration is:
# [244]	training's multi_logloss: 0.830517	training's macroF1: 0.694967	valid_1's multi_logloss: 1.02167	valid_1's macroF1: 0.452781
# ******************** Execution ended in 00h 00m 11.40s ********************
# ============================== 2 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.643596	training's macroF1: 0.768444	valid_1's multi_logloss: 0.981158	valid_1's macroF1: 0.432482
# Early stopping, best iteration is:
# [393]	training's multi_logloss: 0.708409	training's macroF1: 0.744371	valid_1's multi_logloss: 0.984434	valid_1's macroF1: 0.468271
# ******************** Execution ended in 00h 00m 15.20s ********************
# ============================== 3 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.647043	training's macroF1: 0.763032	valid_1's multi_logloss: 1.00522	valid_1's macroF1: 0.448634
# Early stopping, best iteration is:
# [357]	training's multi_logloss: 0.739014	training's macroF1: 0.727988	valid_1's multi_logloss: 1.01938	valid_1's macroF1: 0.468833
# ******************** Execution ended in 00h 00m 12.63s ********************
# ============================== 4 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.640619	training's macroF1: 0.771224	valid_1's multi_logloss: 0.967028	valid_1's macroF1: 0.421862
# Early stopping, best iteration is:
# [420]	training's multi_logloss: 0.688784	training's macroF1: 0.747642	valid_1's multi_logloss: 0.974799	valid_1's macroF1: 0.445544
# ******************** Execution ended in 00h 00m 13.37s ********************
# ============================== 5 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.635591	training's macroF1: 0.772811	valid_1's multi_logloss: 1.01783	valid_1's macroF1: 0.362307
# Early stopping, best iteration is:
# [55]	training's multi_logloss: 1.13344	training's macroF1: 0.606712	valid_1's multi_logloss: 1.16738	valid_1's macroF1: 0.388719
# ******************** Execution ended in 00h 00m 07.07s ********************
# ============================== 6 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.633855	training's macroF1: 0.779466	valid_1's multi_logloss: 1.07142	valid_1's macroF1: 0.383863
# [1000]	training's multi_logloss: 0.445486	training's macroF1: 0.844612	valid_1's multi_logloss: 1.06628	valid_1's macroF1: 0.407406
# Early stopping, best iteration is:
# [878]	training's multi_logloss: 0.478931	training's macroF1: 0.834865	valid_1's multi_logloss: 1.06571	valid_1's macroF1: 0.409436
# ******************** Execution ended in 00h 00m 27.03s ********************
# ============================== 7 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.634476	training's macroF1: 0.775759	valid_1's multi_logloss: 0.97514	valid_1's macroF1: 0.413754
# Early stopping, best iteration is:
# [168]	training's multi_logloss: 0.909439	training's macroF1: 0.67333	valid_1's multi_logloss: 1.02007	valid_1's macroF1: 0.433317
# ******************** Execution ended in 00h 00m 09.11s ********************
# ============================== 8 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.636907	training's macroF1: 0.774107	valid_1's multi_logloss: 0.973946	valid_1's macroF1: 0.413901
# Early stopping, best iteration is:
# [308]	training's multi_logloss: 0.766241	training's macroF1: 0.720793	valid_1's multi_logloss: 0.995116	valid_1's macroF1: 0.445876
# ******************** Execution ended in 00h 00m 11.23s ********************
# ============================== 9 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.644612	training's macroF1: 0.766707	valid_1's multi_logloss: 0.898259	valid_1's macroF1: 0.481893
# [1000]	training's multi_logloss: 0.457368	training's macroF1: 0.835495	valid_1's multi_logloss: 0.861779	valid_1's macroF1: 0.502605
# [1500]	training's multi_logloss: 0.361609	training's macroF1: 0.871503	valid_1's multi_logloss: 0.843731	valid_1's macroF1: 0.515781
# Early stopping, best iteration is:
# [1438]	training's multi_logloss: 0.370986	training's macroF1: 0.867268	valid_1's multi_logloss: 0.846223	valid_1's macroF1: 0.521306
# ******************** Execution ended in 00h 00m 34.54s ********************
# ============================== 10 of 10 folds ==============================
# [LightGBM] [Warning] seed is set=1989, random_state=1989 will be ignored. Current value: seed=1989
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.641278	training's macroF1: 0.767819	valid_1's multi_logloss: 0.989139	valid_1's macroF1: 0.387369
# Early stopping, best iteration is:
# [305]	training's multi_logloss: 0.77084	training's macroF1: 0.71176	valid_1's multi_logloss: 1.00018	valid_1's macroF1: 0.402042
# ******************** Execution ended in 00h 00m 11.22s ********************

# %%
submission['Target'] = np.array(predicts_result).mean(axis=0).round().astype(int)
submission.to_csv('submission_shap_randomized_search.csv', index = False)
